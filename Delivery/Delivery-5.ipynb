# %% [markdown]
# # 🚚 Проект: предсказание опозданий доставки
#
# В этом проекте проводится анализ логистических данных с целью предсказания того, будет ли доставка произведена вовремя. Основное внимание уделено повышению полноты (recall) модели при контроле за точностью (precision).

# %% [markdown]
# ## 📈 Проверка статистических гипотез

# %%
# импорт библиотек и метрик
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from scipy import stats as st


from sklearn.linear_model import LinearRegression, LogisticRegression
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier, plot_tree, export_text
from sklearn.ensemble import RandomForestClassifier
from sklearn.pipeline import Pipeline
from sklearn.metrics import (accuracy_score, precision_score, recall_score, f1_score, 
                            ConfusionMatrixDisplay, confusion_matrix, roc_curve, roc_auc_score, mean_absolute_error,
                            precision_recall_curve, roc_curve, auc)
from sklearn.preprocessing import StandardScaler, MinMaxScaler, OneHotEncoder, OrdinalEncoder
from sklearn.model_selection import train_test_split, cross_val_score, GridSearchCV, RandomizedSearchCV, ParameterGrid, StratifiedKFold
from sklearn.impute import SimpleImputer
from sklearn.compose import ColumnTransformer
from sklearn.base import clone
from sklearn.feature_selection import SelectKBest, f_classif

from optuna.distributions import IntDistribution, FloatDistribution, CategoricalDistribution
from optuna.integration import OptunaSearchCV

import time
from tqdm import tqdm
import re

from sklearn.datasets import fetch_california_housing

from catboost import CatBoostRegressor, CatBoostClassifier, Pool
from lightgbm import LGBMRegressor, LGBMClassifier
from xgboost import XGBRegressor, XGBClassifier

from scipy.stats import chi2_contingency, ttest_1samp

from IPython.display import display, Markdown

import re
import warnings
warnings.filterwarnings("ignore", category=UserWarning, module='sklearn.utils.validation')

# %% [markdown]
# ## 📁 Загрузка и первичный анализ данных

# %%
data = pd.read_csv('Delivery.csv')

# %%
display(data.head(10))
data.info()
# Out:
#    ID Warehouse_block Mode_of_Shipment  Customer_care_calls  Customer_rating  \
# 0   1               D           Flight                    4                2
# 1   2               F           Flight                    4                5
# 2   3               A           Flight                    2                2
# 3   4               B           Flight                    3                3
# 4   5               C           Flight                    2                2
# 5   6               F           Flight                    3                1
# 6   7               D           Flight                    3                4
# 7   8               F           Flight                    4                1
# 8   9               A           Flight                    3                4
# 9  10               B           Flight                    3                2
#
#    Cost_of_the_Product  Prior_purchases Product_importance Gender  \
# 0                  177                3                low      F
# 1                  216                2                low      M
# 2                  183                4                low      M
# 3                  176                4             medium      M
# 4                  184                3             medium      F
# 5                  162                3             medium      F
# 6                  250                3                low      F
# 7                  233                2                low      F
# 8                  150                3                low      F
# 9                  164                3             medium      F
#
#    Discount_offered  Weight_in_gms  Reached.on.Time_Y.N
# 0                44           1233                    1
# 1                59           3088                    1
# 2                48           3374                    1
# 3                10           1177                    1
# 4                46           2484                    1
# 5                12           1417                    1
# 6                 3           2371                    1
# 7                48           2804                    1
# 8                11           1861                    1
# 9                29           1187                    1
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10999 entries, 0 to 10998
# Data columns (total 12 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   ID                   10999 non-null  int64
#  1   Warehouse_block      10999 non-null  object
#  2   Mode_of_Shipment     10999 non-null  object
#  3   Customer_care_calls  10999 non-null  int64
#  4   Customer_rating      10999 non-null  int64
#  5   Cost_of_the_Product  10999 non-null  int64
#  6   Prior_purchases      10999 non-null  int64
#  7   Product_importance   10999 non-null  object
#  8   Gender               10999 non-null  object
#  9   Discount_offered     10999 non-null  int64
#  10  Weight_in_gms        10999 non-null  int64
#  11  Reached.on.Time_Y.N  10999 non-null  int64
# dtypes: int64(8), object(4)
# memory usage: 1.0+ MB

# %%
data = data.drop('ID', axis = 1)

# %%
def to_snake_case(name):
    name = re.sub('(.)([A-Z][a-z]+)', r'\1_\2', name)
    name = re.sub('([a-z0-9])([A-Z])', r'\1_\2', name)
    return name.lower()

data.columns = [to_snake_case(col) for col in data.columns]
data = data.rename(columns={'reached.on._time_y.n' : 'time', 'weight_in_gms' : 'weight', 'mode_of__shipment' : 'mode_of_shipment', 'cost_of_the__product' : 'price','discount_offered' : 'discount'})
display(data.head(0))
# Out:
# Empty DataFrame
# Columns: [warehouse_block, mode_of_shipment, customer_care_calls, customer_rating, price, prior_purchases, product_importance, gender, discount, weight, time]
# Index: []

# %% [markdown]
# ## 🔍 Предобработка данных и очистка

# %%
def preprocessor(df):
    print('Количество пропусков в каждом из столбцов:')
    print(df.isna().sum())
    print("-" * 50)
    
    print(f'Количество дубликатов: {df.duplicated().sum()}')
    print("-" * 50)

    for col in df.select_dtypes(include='object').columns:
        print(f"Столбец: {col}")
        print(df[col].unique())
        print("-" * 50)

# %%
preprocessor(data)
# Out:
# Количество пропусков в каждом из столбцов:
# warehouse_block        0
# mode_of_shipment       0
# customer_care_calls    0
# customer_rating        0
# price                  0
# prior_purchases        0
# product_importance     0
# gender                 0
# discount               0
# weight                 0
# time                   0
# dtype: int64
# --------------------------------------------------
# Количество дубликатов: 0
# --------------------------------------------------
# Столбец: warehouse_block
# ['D' 'F' 'A' 'B' 'C']
# --------------------------------------------------
# Столбец: mode_of_shipment
# ['Flight' 'Ship' 'Road']
# --------------------------------------------------
# Столбец: product_importance
# ['low' 'medium' 'high']
# --------------------------------------------------
# Столбец: gender
# ['F' 'M']
# --------------------------------------------------

# %% [markdown]
# ## 📊 Анализ целевого признака (вовремя / не вовремя)

# %%
data['time'].value_counts().plot(kind='bar')
plt.title('Опоздал ли курьер')
plt.xticks(rotation=0)
plt.show()
data['time'].value_counts()
# Out:
# time
# 1    6563
# 0    4436
# Name: count, dtype: int64

# %% [markdown]
# ## 📊 Исследовательский анализ категориальных признаков

# %%
categorical_cols = data.select_dtypes(include='object').columns

for col in categorical_cols:
    fig, axes = plt.subplots(1, 2, figsize=(12, 5))

    churn_dist = (
        data.groupby(col)['time']
        .value_counts(normalize=True)
        .rename('proportion')
        .reset_index()
    )

    sns.barplot(
        x=col,
        y='proportion',
        hue='time',
        data=churn_dist,
        ax=axes[0]
    )
    axes[0].set_title(f'Распределение churn по {col}')
    axes[0].set_ylabel('Доля доставок')
    axes[0].tick_params(axis='x', rotation=0)
    axes[0].set_ylim(0, 1) 

    pie_counts = data[col].value_counts()
    wedges, texts, autotexts = axes[1].pie(
        pie_counts,
        labels=pie_counts.index,
        autopct='%1.0f%%',
        startangle=140
    )
    axes[1].set_title(f'Распределение значений {col}')
    for text in texts + autotexts:
        text.set_fontsize(10)

    plt.tight_layout()
    plt.show()

# %%
data.describe().T
# Out:
#                        count         mean          std     min     25%  \
# customer_care_calls  10999.0     4.054459     1.141490     2.0     3.0
# customer_rating      10999.0     2.990545     1.413603     1.0     2.0
# price                10999.0   210.196836    48.063272    96.0   169.0
# prior_purchases      10999.0     3.567597     1.522860     2.0     3.0
# discount             10999.0    13.373216    16.205527     1.0     4.0
# weight               10999.0  3634.016729  1635.377251  1001.0  1839.5
# time                 10999.0     0.596691     0.490584     0.0     0.0
#
#                         50%     75%     max
# customer_care_calls     4.0     5.0     7.0
# customer_rating         3.0     4.0     5.0
# price                 214.0   251.0   310.0
# prior_purchases         3.0     4.0    10.0
# discount                7.0    10.0    65.0
# weight               4149.0  5050.0  7846.0
# time                    1.0     1.0     1.0

# %% [markdown]
# ## 📊 Исследование числовых признаков

# %%
numerical_cols = data.select_dtypes(include='number').columns.drop('time', errors='ignore')

for col in numerical_cols:
    fig, axes = plt.subplots(1, 2, figsize=(12, 4))
    
    # Гистограмма
    sns.histplot(data[col], bins=30, kde=True, ax=axes[0])
    axes[0].set_title(f'Распределение {col}')
    axes[0].set_xlabel(col)
    axes[0].set_ylabel('Частота')
    
    # Диаграмма размаха
    sns.boxplot(x=data[col], ax=axes[1])
    axes[1].set_title(f'Ящиковая диаграмма {col}')
    axes[1].set_xlabel(col)

    plt.tight_layout()
    plt.show()

# %%
def classify_weight(weight):
    if weight < 2000:
        return 'light'
    elif weight < 4000:
        return 'medium'
    else:
        return 'heavy'

data['weight_class'] = data['weight'].apply(classify_weight)
cols = list(data.columns)

i, j = cols.index('time'), cols.index('weight_class')

cols[i], cols[j] = cols[j], cols[i]

data = data[cols]

display(data[['weight', 'weight_class']].head(5))
display(data[['weight', 'weight_class']].query('weight >= 4000').head(5))
# Out:
#    weight weight_class
# 0    1233        light
# 1    3088       medium
# 2    3374       medium
# 3    1177        light
# 4    2484       medium
#      weight weight_class
# 198    7640        heavy
# 199    7846        heavy
# 205    7588        heavy
# 213    7401        heavy
# 244    6064        heavy

# %% [markdown]
# ## 📌 Корреляционный анализ и важность признаков

# %%
def cramers_v(x, y):
    confusion_matrix = pd.crosstab(x, y)
    chi2 = chi2_contingency(confusion_matrix)[0]
    n = confusion_matrix.sum().sum()
    r, k = confusion_matrix.shape
    return np.sqrt(chi2 / (n * (min(k, r) - 1)))

numeric_cols = data.select_dtypes(include='number').columns.drop('time')
num_corr = data[numeric_cols].corrwith(data['time']).abs()
num_corr = pd.DataFrame({'feature': num_corr.index, 'correlation': num_corr.values})

cat_cols = data.select_dtypes(include='object').columns
cat_corr = {col: cramers_v(data[col], data['time']) for col in cat_cols}
cat_corr = pd.DataFrame({'feature': list(cat_corr.keys()), 'correlation': list(cat_corr.values())})

all_corr = pd.concat([num_corr, cat_corr], ignore_index=True)
all_corr = all_corr.sort_values(by='correlation', ascending=False)

plt.figure(figsize=(16, 8))
sns.barplot(
    data=all_corr,
    x='feature',
    y='correlation',
    palette=sns.color_palette('rocket', n_colors=len(all_corr)) 
)
plt.axhline(y=0.03, color='red', linestyle='-')
plt.xticks(rotation=45, ha='right')
plt.title('Общая сила связи признаков с churn', fontsize=14)
plt.ylabel('Значение корреляции / силы связи')
plt.tight_layout()
plt.show()
# Out:
# /var/folders/1j/wgf74c1d3f116n7z14dqwqcr0000gn/T/ipykernel_19729/973055969.py:20: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(

# %%
data = data.drop(['warehouse_block', 'customer_care_calls', 'product_importance', 'customer_rating'], axis = 1)

# %%
corr_data = data.copy()

cat_cols = corr_data.select_dtypes(include='object').columns
encoder = OrdinalEncoder()
corr_data[cat_cols] = encoder.fit_transform(corr_data[cat_cols])

corr_matrix = corr_data.corr()

plt.figure(figsize=(16, 12))
sns.heatmap(corr_matrix, annot=True, fmt=".2f", cmap="coolwarm", linewidths=0.5)
plt.title("Матрица корреляции всех признаков (включая категориальные)")
plt.show()

# %% [markdown]
# ## 📈 Проверка статистических гипотез

# %%
a = 0.05

contingency_table = pd.crosstab(data['mode_of_shipment'], data['time'])

chi2, p, dof, expected = chi2_contingency(contingency_table)

print(f"p-value: {p:.4f}")
if p < a:
    print("❗ Зависимость между опозданием и типом доставки статистически значима.")
else:
    print("✅ Нет статистически значимой зависимости между опозданием и типом доставки.")
# Out:
# p-value: 0.6895
# ✅ Нет статистически значимой зависимости между опозданием и типом доставки.

# %%
delayed_prices = data[data['time'] == 1]['price']

t_stat, p = ttest_1samp(delayed_prices, 207)

print(f"p-value: {p:.4f}")
if p < a:
    print("❗ Средняя цена у опоздавших товаров статистически отличается от 207.")
else:
    print("✅ Средняя цена у опоздавших товаров статистически не отличается от 207.")
# Out:
# p-value: 0.6259
# ✅ Средняя цена у опоздавших товаров статистически не отличается от 207.

# %%
contingency_table = pd.crosstab(data['weight_class'], data['time'])

chi2, p, _, _ = chi2_contingency(contingency_table)

print("Хи-квадрат:", chi2)
print("p-value:", p)

if p < 0.05:
    print("✅ Зависимость между типом веса и опозданием статистически значима.")
    print("🔍 Частота опозданий по весовым категориям:")
    display(contingency_table.div(contingency_table.sum(axis=1), axis=0)) 
else:
    print("❌ Зависимость между типом веса и опозданием не подтверждена статистически.")
# Out:
# Хи-квадрат: 1964.8291330257268
# p-value: 0.0
# ✅ Зависимость между типом веса и опозданием статистически значима.
# 🔍 Частота опозданий по весовым категориям:
# time                 0         1
# weight_class
# heavy         0.568029  0.431971
# light         0.322123  0.677877
# medium        0.001117  0.998883

# %%
display(data.head(10))
# Out:
#   mode_of_shipment  price  prior_purchases gender  discount  weight  \
# 0           Flight    177                3      F        44    1233
# 1           Flight    216                2      M        59    3088
# 2           Flight    183                4      M        48    3374
# 3           Flight    176                4      M        10    1177
# 4           Flight    184                3      F        46    2484
# 5           Flight    162                3      F        12    1417
# 6           Flight    250                3      F         3    2371
# 7           Flight    233                2      F        48    2804
# 8           Flight    150                3      F        11    1861
# 9           Flight    164                3      F        29    1187
#
#   weight_class  time
# 0        light     1
# 1       medium     1
# 2       medium     1
# 3        light     1
# 4       medium     1
# 5        light     1
# 6       medium     1
# 7       medium     1
# 8        light     1
# 9        light     1

# %% [markdown]
# ## ✂️ Разделение данных на обучающую и тестовую выборки

# %%
target = 'time'

RANDOM_STATE = 42
TEST_SIZE = 0.2

X = data.drop(columns=[target], axis = 1) 
y = data[target]

X_train, X_test, y_train, y_test = train_test_split(X, 
                                                    y, 
                                                    test_size=TEST_SIZE, 
                                                    stratify=y, 
                                                    random_state=RANDOM_STATE)

# %%
ohe_col = X.select_dtypes(include='object').columns.difference(['weight_class']).tolist()
ord_col = ['weight_class']
num_col = X.select_dtypes(exclude='object').columns.tolist()

print(ohe_col)
print(ord_col)
print(num_col)
# Out:
# ['gender', 'mode_of_shipment']
# ['weight_class']
# ['price', 'prior_purchases', 'discount', 'weight']

# %% [markdown]
# ## ⚙️ Построение пайплайна предобработки

# %%
ohe_pipe = Pipeline([
    ('imputer', SimpleImputer(strategy='most_frequent')),
    ('ohe', OneHotEncoder(drop='first', handle_unknown='ignore', sparse_output=False))
])

ord_pipe = Pipeline([
    ('imputer1', SimpleImputer(strategy='most_frequent')),
    ('ord', OrdinalEncoder(categories=[['light', 'medium', 'heavy']],
                           handle_unknown='use_encoded_value', unknown_value=np.nan)),
    ('imputer2', SimpleImputer(strategy='most_frequent'))
])

num_pipe = Pipeline([
    ('imputer', SimpleImputer(strategy='mean')),
    ('scaler', StandardScaler())
])

data_preprocessor = ColumnTransformer([
    ('ohe', ohe_pipe, ohe_col),
    ('ord', ord_pipe, ord_col),
    ('num', num_pipe, num_col)
], remainder='drop')

pipe_final = Pipeline([
    ('preprocessor', data_preprocessor),
    ('feature_selection', SelectKBest(score_func=f_classif, k=10)),
    ('models', LogisticRegression())
])

param_grid = [
    {
        'models': [CatBoostClassifier(verbose=0)],
        'models__depth': [4, 6, 8],
        'models__learning_rate': [0.03, 0.1],
        'models__iterations': [100, 200],
        'feature_selection__k': [5, 10, 'all']
    },
    {
        'models': [LGBMClassifier(verbose=-1)],
        'models__n_estimators': [100, 200],
        'models__max_depth': [5, 10],
        'models__learning_rate': [0.05, 0.1],
        'feature_selection__k': [5, 10, 'all']
    },
    {
        'models': [LogisticRegression(random_state=RANDOM_STATE, solver='liblinear')],
        'models__C': range(1, 15),
        'preprocessor__num__scaler': [StandardScaler(), MinMaxScaler()],
        'feature_selection__k': [5, 10, 'all']
    },
    {
        'models': [RandomForestClassifier(random_state=RANDOM_STATE)],
        'models__n_estimators': [100, 200],
        'models__max_depth': [5, 10],
        'models__min_samples_split': [2, 5],
        'feature_selection__k': [5, 10, 'all']
    }
]
print(a)
# Out:
# 0.05

# %% [markdown]
# ## 🤖 Подбор модели с кросс-валидацией и GridSearch

# %%
grid = GridSearchCV(
    pipe_final,
    param_grid,
    cv=3,
    scoring='recall',
    n_jobs=-1,
    verbose=2
)
grid.fit(X_train, y_train)
# Out:
# Fitting 3 folds for each of 168 candidates, totalling 504 fits
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/feature_selection/_univariate_selection.py:783: UserWarning: k=10 is greater than n_features=8. All the features will be returned.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/feature_selection/_univariate_selection.py:783: UserWarning: k=10 is greater than n_features=8. All the features will be returned.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/feature_selection/_univariate_selection.py:783: UserWarning: k=10 is greater than n_features=8. All the features will be returned.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/feature_selection/_univariate_selection.py:783: UserWarning: k=10 is greater than n_features=8. All the features will be returned.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/feature_selection/_univariate_selection.py:783: UserWarning: k=10 is greater than n_features=8. All the features will be returned.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/feature_selection/_univariate_selection.py:783: UserWarning: k=10 is greater than n_features=8. All the features will be returned.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/feature_selection/_univariate_selection.py:783: UserWarning: k=10 is greater than n_features=8. All the features will be returned.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/feature_selection/_univariate_selection.py:783: UserWarning: k=10 is greater than n_features=8. All the features will be returned.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/feature_selection/_univariate_selection.py:783: UserWarning: k=10 is greater than n_features=8. All the features will be returned.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/feature_selection/_univariate_selection.py:783: UserWarning: k=10 is greater than n_features=8. All the features will be returned.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/feature_selection/_univariate_selection.py:783: UserWarning: k=10 is greater than n_features=8. All the features will be returned.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/feature_selection/_univariate_selection.py:783: UserWarning: k=10 is greater than n_features=8. All the features will be returned.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/feature_selection/_univariate_selection.py:783: UserWarning: k=10 is greater than n_features=8. All the features will be returned.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/feature_selection/_univariate_selection.py:783: UserWarning: k=10 is greater than n_features=8. All the features will be returned.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/feature_selection/_univariate_selection.py:783: UserWarning: k=10 is greater than n_features=8. All the features will be returned.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/feature_selection/_univariate_selection.py:783: UserWarning: k=10 is greater than n_features=8. All the features will be returned.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/feature_selection/_univariate_selection.py:783: UserWarning: k=10 is greater than n_features=8. All the features will be returned.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/feature_selection/_univariate_selection.py:783: UserWarning: k=10 is greater than n_features=8. All the features will be returned.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/feature_selection/_univariate_selection.py:783: UserWarning: k=10 is greater than n_features=8. All the features will be returned.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/feature_selection/_univariate_selection.py:783: UserWarning: k=10 is greater than n_features=8. All the features will be returned.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/feature_selection/_univariate_selection.py:783: UserWarning: k=10 is greater than n_features=8. All the features will be returned.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/feature_selection/_univariate_selection.py:783: UserWarning: k=10 is greater than n_features=8. All the features will be returned.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/feature_selection/_univariate_selection.py:783: UserWarning: k=10 is greater than n_features=8. All the features will be returned.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/feature_selection/_univariate_selection.py:783: UserWarning: k=10 is greater than n_features=8. All the features will be returned.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/feature_selection/_univariate_selection.py:783: UserWarning: k=10 is greater than n_features=8. All the features will be returned.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/feature_selection/_univariate_selection.py:783: UserWarning: k=10 is greater than n_features=8. All the features will be returned.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/feature_selection/_univariate_selection.py:783: UserWarning: k=10 is greater than n_features=8. All the features will be returned.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/feature_selection/_univariate_selection.py:783: UserWarning: k=10 is greater than n_features=8. All the features will be returned.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/feature_selection/_univariate_selection.py:783: UserWarning: k=10 is greater than n_features=8. All the features will be returned.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/feature_selection/_univariate_selection.py:783: UserWarning: k=10 is greater than n_features=8. All the features will be returned.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/feature_selection/_univariate_selection.py:783: UserWarning: k=10 is greater than n_features=8. All the features will be returned.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/feature_selection/_univariate_selection.py:783: UserWarning: k=10 is greater than n_features=8. All the features will be returned.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/feature_selection/_univariate_selection.py:783: UserWarning: k=10 is greater than n_features=8. All the features will be returned.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/feature_selection/_univariate_selection.py:783: UserWarning: k=10 is greater than n_features=8. All the features will be returned.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/feature_selection/_univariate_selection.py:783: UserWarning: k=10 is greater than n_features=8. All the features will be returned.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/feature_selection/_univariate_selection.py:783: UserWarning: k=10 is greater than n_features=8. All the features will be returned.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/feature_selection/_univariate_selection.py:783: UserWarning: k=10 is greater than n_features=8. All the features will be returned.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/feature_selection/_univariate_selection.py:783: UserWarning: k=10 is greater than n_features=8. All the features will be returned.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/feature_selection/_univariate_selection.py:783: UserWarning: k=10 is greater than n_features=8. All the features will be returned.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/feature_selection/_univariate_selection.py:783: UserWarning: k=10 is greater than n_features=8. All the features will be returned.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/feature_selection/_univariate_selection.py:783: UserWarning: k=10 is greater than n_features=8. All the features will be returned.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/feature_selection/_univariate_selection.py:783: UserWarning: k=10 is greater than n_features=8. All the features will be returned.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/feature_selection/_univariate_selection.py:783: UserWarning: k=10 is greater than n_features=8. All the features will be returned.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/feature_selection/_univariate_selection.py:783: UserWarning: k=10 is greater than n_features=8. All the features will be returned.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/feature_selection/_univariate_selection.py:783: UserWarning: k=10 is greater than n_features=8. All the features will be returned.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/feature_selection/_univariate_selection.py:783: UserWarning: k=10 is greater than n_features=8. All the features will be returned.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/feature_selection/_univariate_selection.py:783: UserWarning: k=10 is greater than n_features=8. All the features will be returned.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/feature_selection/_univariate_selection.py:783: UserWarning: k=10 is greater than n_features=8. All the features will be returned.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/feature_selection/_univariate_selection.py:783: UserWarning: k=10 is greater than n_features=8. All the features will be returned.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/feature_selection/_univariate_selection.py:783: UserWarning: k=10 is greater than n_features=8. All the features will be returned.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/feature_selection/_univariate_selection.py:783: UserWarning: k=10 is greater than n_features=8. All the features will be returned.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/feature_selection/_univariate_selection.py:783: UserWarning: k=10 is greater than n_features=8. All the features will be returned.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/feature_selection/_univariate_selection.py:783: UserWarning: k=10 is greater than n_features=8. All the features will be returned.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/feature_selection/_univariate_selection.py:783: UserWarning: k=10 is greater than n_features=8. All the features will be returned.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/feature_selection/_univariate_selection.py:783: UserWarning: k=10 is greater than n_features=8. All the features will be returned.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/feature_selection/_univariate_selection.py:783: UserWarning: k=10 is greater than n_features=8. All the features will be returned.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/feature_selection/_univariate_selection.py:783: UserWarning: k=10 is greater than n_features=8. All the features will be returned.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/feature_selection/_univariate_selection.py:783: UserWarning: k=10 is greater than n_features=8. All the features will be returned.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/feature_selection/_univariate_selection.py:783: UserWarning: k=10 is greater than n_features=8. All the features will be returned.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/feature_selection/_univariate_selection.py:783: UserWarning: k=10 is greater than n_features=8. All the features will be returned.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/feature_selection/_univariate_selection.py:783: UserWarning: k=10 is greater than n_features=8. All the features will be returned.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/feature_selection/_univariate_selection.py:783: UserWarning: k=10 is greater than n_features=8. All the features will be returned.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/feature_selection/_univariate_selection.py:783: UserWarning: k=10 is greater than n_features=8. All the features will be returned.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/feature_selection/_univariate_selection.py:783: UserWarning: k=10 is greater than n_features=8. All the features will be returned.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/feature_selection/_univariate_selection.py:783: UserWarning: k=10 is greater than n_features=8. All the features will be returned.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/feature_selection/_univariate_selection.py:783: UserWarning: k=10 is greater than n_features=8. All the features will be returned.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/feature_selection/_univariate_selection.py:783: UserWarning: k=10 is greater than n_features=8. All the features will be returned.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/feature_selection/_univariate_selection.py:783: UserWarning: k=10 is greater than n_features=8. All the features will be returned.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/feature_selection/_univariate_selection.py:783: UserWarning: k=10 is greater than n_features=8. All the features will be returned.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/feature_selection/_univariate_selection.py:783: UserWarning: k=10 is greater than n_features=8. All the features will be returned.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/feature_selection/_univariate_selection.py:783: UserWarning: k=10 is greater than n_features=8. All the features will be returned.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/feature_selection/_univariate_selection.py:783: UserWarning: k=10 is greater than n_features=8. All the features will be returned.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/feature_selection/_univariate_selection.py:783: UserWarning: k=10 is greater than n_features=8. All the features will be returned.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/feature_selection/_univariate_selection.py:783: UserWarning: k=10 is greater than n_features=8. All the features will be returned.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/feature_selection/_univariate_selection.py:783: UserWarning: k=10 is greater than n_features=8. All the features will be returned.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/feature_selection/_univariate_selection.py:783: UserWarning: k=10 is greater than n_features=8. All the features will be returned.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/feature_selection/_univariate_selection.py:783: UserWarning: k=10 is greater than n_features=8. All the features will be returned.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/feature_selection/_univariate_selection.py:783: UserWarning: k=10 is greater than n_features=8. All the features will be returned.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/feature_selection/_univariate_selection.py:783: UserWarning: k=10 is greater than n_features=8. All the features will be returned.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/feature_selection/_univariate_selection.py:783: UserWarning: k=10 is greater than n_features=8. All the features will be returned.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/feature_selection/_univariate_selection.py:783: UserWarning: k=10 is greater than n_features=8. All the features will be returned.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/feature_selection/_univariate_selection.py:783: UserWarning: k=10 is greater than n_features=8. All the features will be returned.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/feature_selection/_univariate_selection.py:783: UserWarning: k=10 is greater than n_features=8. All the features will be returned.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/feature_selection/_univariate_selection.py:783: UserWarning: k=10 is greater than n_features=8. All the features will be returned.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/feature_selection/_univariate_selection.py:783: UserWarning: k=10 is greater than n_features=8. All the features will be returned.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/feature_selection/_univariate_selection.py:783: UserWarning: k=10 is greater than n_features=8. All the features will be returned.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/feature_selection/_univariate_selection.py:783: UserWarning: k=10 is greater than n_features=8. All the features will be returned.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/feature_selection/_univariate_selection.py:783: UserWarning: k=10 is greater than n_features=8. All the features will be returned.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/feature_selection/_univariate_selection.py:783: UserWarning: k=10 is greater than n_features=8. All the features will be returned.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/feature_selection/_univariate_selection.py:783: UserWarning: k=10 is greater than n_features=8. All the features will be returned.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/feature_selection/_univariate_selection.py:783: UserWarning: k=10 is greater than n_features=8. All the features will be returned.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/feature_selection/_univariate_selection.py:783: UserWarning: k=10 is greater than n_features=8. All the features will be returned.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/feature_selection/_univariate_selection.py:783: UserWarning: k=10 is greater than n_features=8. All the features will be returned.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/feature_selection/_univariate_selection.py:783: UserWarning: k=10 is greater than n_features=8. All the features will be returned.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/feature_selection/_univariate_selection.py:783: UserWarning: k=10 is greater than n_features=8. All the features will be returned.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/feature_selection/_univariate_selection.py:783: UserWarning: k=10 is greater than n_features=8. All the features will be returned.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/feature_selection/_univariate_selection.py:783: UserWarning: k=10 is greater than n_features=8. All the features will be returned.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/feature_selection/_univariate_selection.py:783: UserWarning: k=10 is greater than n_features=8. All the features will be returned.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/feature_selection/_univariate_selection.py:783: UserWarning: k=10 is greater than n_features=8. All the features will be returned.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/feature_selection/_univariate_selection.py:783: UserWarning: k=10 is greater than n_features=8. All the features will be returned.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/feature_selection/_univariate_selection.py:783: UserWarning: k=10 is greater than n_features=8. All the features will be returned.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/feature_selection/_univariate_selection.py:783: UserWarning: k=10 is greater than n_features=8. All the features will be returned.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/feature_selection/_univariate_selection.py:783: UserWarning: k=10 is greater than n_features=8. All the features will be returned.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/feature_selection/_univariate_selection.py:783: UserWarning: k=10 is greater than n_features=8. All the features will be returned.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/feature_selection/_univariate_selection.py:783: UserWarning: k=10 is greater than n_features=8. All the features will be returned.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/feature_selection/_univariate_selection.py:783: UserWarning: k=10 is greater than n_features=8. All the features will be returned.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/feature_selection/_univariate_selection.py:783: UserWarning: k=10 is greater than n_features=8. All the features will be returned.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/feature_selection/_univariate_selection.py:783: UserWarning: k=10 is greater than n_features=8. All the features will be returned.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/feature_selection/_univariate_selection.py:783: UserWarning: k=10 is greater than n_features=8. All the features will be returned.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/feature_selection/_univariate_selection.py:783: UserWarning: k=10 is greater than n_features=8. All the features will be returned.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/feature_selection/_univariate_selection.py:783: UserWarning: k=10 is greater than n_features=8. All the features will be returned.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/feature_selection/_univariate_selection.py:783: UserWarning: k=10 is greater than n_features=8. All the features will be returned.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/feature_selection/_univariate_selection.py:783: UserWarning: k=10 is greater than n_features=8. All the features will be returned.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/feature_selection/_univariate_selection.py:783: UserWarning: k=10 is greater than n_features=8. All the features will be returned.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/feature_selection/_univariate_selection.py:783: UserWarning: k=10 is greater than n_features=8. All the features will be returned.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/feature_selection/_univariate_selection.py:783: UserWarning: k=10 is greater than n_features=8. All the features will be returned.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/feature_selection/_univariate_selection.py:783: UserWarning: k=10 is greater than n_features=8. All the features will be returned.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/feature_selection/_univariate_selection.py:783: UserWarning: k=10 is greater than n_features=8. All the features will be returned.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/feature_selection/_univariate_selection.py:783: UserWarning: k=10 is greater than n_features=8. All the features will be returned.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/feature_selection/_univariate_selection.py:783: UserWarning: k=10 is greater than n_features=8. All the features will be returned.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/feature_selection/_univariate_selection.py:783: UserWarning: k=10 is greater than n_features=8. All the features will be returned.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/feature_selection/_univariate_selection.py:783: UserWarning: k=10 is greater than n_features=8. All the features will be returned.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/feature_selection/_univariate_selection.py:783: UserWarning: k=10 is greater than n_features=8. All the features will be returned.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/feature_selection/_univariate_selection.py:783: UserWarning: k=10 is greater than n_features=8. All the features will be returned.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/feature_selection/_univariate_selection.py:783: UserWarning: k=10 is greater than n_features=8. All the features will be returned.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/feature_selection/_univariate_selection.py:783: UserWarning: k=10 is greater than n_features=8. All the features will be returned.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/feature_selection/_univariate_selection.py:783: UserWarning: k=10 is greater than n_features=8. All the features will be returned.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/feature_selection/_univariate_selection.py:783: UserWarning: k=10 is greater than n_features=8. All the features will be returned.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/feature_selection/_univariate_selection.py:783: UserWarning: k=10 is greater than n_features=8. All the features will be returned.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/feature_selection/_univariate_selection.py:783: UserWarning: k=10 is greater than n_features=8. All the features will be returned.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/feature_selection/_univariate_selection.py:783: UserWarning: k=10 is greater than n_features=8. All the features will be returned.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/feature_selection/_univariate_selection.py:783: UserWarning: k=10 is greater than n_features=8. All the features will be returned.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/feature_selection/_univariate_selection.py:783: UserWarning: k=10 is greater than n_features=8. All the features will be returned.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/feature_selection/_univariate_selection.py:783: UserWarning: k=10 is greater than n_features=8. All the features will be returned.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/feature_selection/_univariate_selection.py:783: UserWarning: k=10 is greater than n_features=8. All the features will be returned.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/feature_selection/_univariate_selection.py:783: UserWarning: k=10 is greater than n_features=8. All the features will be returned.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/feature_selection/_univariate_selection.py:783: UserWarning: k=10 is greater than n_features=8. All the features will be returned.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/feature_selection/_univariate_selection.py:783: UserWarning: k=10 is greater than n_features=8. All the features will be returned.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/feature_selection/_univariate_selection.py:783: UserWarning: k=10 is greater than n_features=8. All the features will be returned.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/feature_selection/_univariate_selection.py:783: UserWarning: k=10 is greater than n_features=8. All the features will be returned.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/feature_selection/_univariate_selection.py:783: UserWarning: k=10 is greater than n_features=8. All the features will be returned.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/feature_selection/_univariate_selection.py:783: UserWarning: k=10 is greater than n_features=8. All the features will be returned.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/feature_selection/_univariate_selection.py:783: UserWarning: k=10 is greater than n_features=8. All the features will be returned.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/feature_selection/_univariate_selection.py:783: UserWarning: k=10 is greater than n_features=8. All the features will be returned.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/feature_selection/_univariate_selection.py:783: UserWarning: k=10 is greater than n_features=8. All the features will be returned.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/feature_selection/_univariate_selection.py:783: UserWarning: k=10 is greater than n_features=8. All the features will be returned.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/feature_selection/_univariate_selection.py:783: UserWarning: k=10 is greater than n_features=8. All the features will be returned.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/feature_selection/_univariate_selection.py:783: UserWarning: k=10 is greater than n_features=8. All the features will be returned.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/feature_selection/_univariate_selection.py:783: UserWarning: k=10 is greater than n_features=8. All the features will be returned.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/feature_selection/_univariate_selection.py:783: UserWarning: k=10 is greater than n_features=8. All the features will be returned.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/feature_selection/_univariate_selection.py:783: UserWarning: k=10 is greater than n_features=8. All the features will be returned.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/feature_selection/_univariate_selection.py:783: UserWarning: k=10 is greater than n_features=8. All the features will be returned.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/feature_selection/_univariate_selection.py:783: UserWarning: k=10 is greater than n_features=8. All the features will be returned.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/feature_selection/_univariate_selection.py:783: UserWarning: k=10 is greater than n_features=8. All the features will be returned.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/feature_selection/_univariate_selection.py:783: UserWarning: k=10 is greater than n_features=8. All the features will be returned.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/feature_selection/_univariate_selection.py:783: UserWarning: k=10 is greater than n_features=8. All the features will be returned.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/feature_selection/_univariate_selection.py:783: UserWarning: k=10 is greater than n_features=8. All the features will be returned.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/feature_selection/_univariate_selection.py:783: UserWarning: k=10 is greater than n_features=8. All the features will be returned.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/feature_selection/_univariate_selection.py:783: UserWarning: k=10 is greater than n_features=8. All the features will be returned.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/feature_selection/_univariate_selection.py:783: UserWarning: k=10 is greater than n_features=8. All the features will be returned.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/feature_selection/_univariate_selection.py:783: UserWarning: k=10 is greater than n_features=8. All the features will be returned.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/feature_selection/_univariate_selection.py:783: UserWarning: k=10 is greater than n_features=8. All the features will be returned.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/feature_selection/_univariate_selection.py:783: UserWarning: k=10 is greater than n_features=8. All the features will be returned.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/feature_selection/_univariate_selection.py:783: UserWarning: k=10 is greater than n_features=8. All the features will be returned.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/feature_selection/_univariate_selection.py:783: UserWarning: k=10 is greater than n_features=8. All the features will be returned.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/feature_selection/_univariate_selection.py:783: UserWarning: k=10 is greater than n_features=8. All the features will be returned.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/feature_selection/_univariate_selection.py:783: UserWarning: k=10 is greater than n_features=8. All the features will be returned.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/feature_selection/_univariate_selection.py:783: UserWarning: k=10 is greater than n_features=8. All the features will be returned.
#   warnings.warn(
# GridSearchCV(cv=3,
#              estimator=Pipeline(steps=[('preprocessor',
#                                         ColumnTransformer(transformers=[('ohe',
#                                                                          Pipeline(steps=[('imputer',
#                                                                                           SimpleImputer(strategy='most_frequent')),
#                                                                                          ('ohe',
#                                                                                           OneHotEncoder(drop='first',
#                                                                                                         handle_unknown='ignore',
#                                                                                                         sparse_output=False))]),
#                                                                          ['gender',
#                                                                           'mode_of_shipment']),
#                                                                         ('ord',
#                                                                          Pipeline(steps=[('imputer1',
#                                                                                           SimpleImputer(strategy='most_freque...
#                           'models': [LogisticRegression(random_state=42,
#                                                         solver='liblinear')],
#                           'models__C': range(1, 15),
#                           'preprocessor__num__scaler': [StandardScaler(),
#                                                         MinMaxScaler()]},
#                          {'feature_selection__k': [5, 10, 'all'],
#                           'models': [RandomForestClassifier(random_state=42)],
#                           'models__max_depth': [5, 10],
#                           'models__min_samples_split': [2, 5],
#                           'models__n_estimators': [100, 200]}],
#              scoring='recall', verbose=2)

# %%
cv_results = pd.DataFrame(grid.cv_results_)

best_per_model = (
    cv_results
    .assign(model_name=cv_results['param_models'].apply(lambda x: x.__class__.__name__))
    .sort_values('mean_test_score', ascending=False)
    .drop_duplicates(subset='model_name', keep='first')
    [['model_name', 'params', 'mean_test_score']]
    .rename(columns={
        'model_name': 'Model',
        'params': 'Best Params',
        'mean_test_score': 'Recall (CV)'
    })
    .reset_index(drop=True)
)

best_per_model = best_per_model.sort_values('Recall (CV)', ascending=False).reset_index(drop=True)

display(best_per_model)

best_model_name = best_per_model.iloc[0]['Model']
display(Markdown(f"**Лучшая модель по метрике Recall: `{best_model_name}`**"))
# Out:
#                     Model                                        Best Params  \
# 0      LogisticRegression  {'feature_selection__k': 5, 'models': Logistic...
# 1          LGBMClassifier  {'feature_selection__k': 'all', 'models': LGBM...
# 2      CatBoostClassifier  {'feature_selection__k': 10, 'models': <catboo...
# 3  RandomForestClassifier  {'feature_selection__k': 10, 'models': RandomF...
#
#    Recall (CV)
# 0     0.683810
# 1     0.645905
# 2     0.634476
# 3     0.564000
# **Лучшая модель по метрике Recall: `LogisticRegression`**

# %% [markdown]
# ## 📌 Важность признаков модели логистической регрессии

# %%
ohe_feature_names = grid.best_estimator_.named_steps['preprocessor'] \
    .named_transformers_['ohe'].named_steps['ohe'].get_feature_names_out(ohe_col)

all_features = list(ohe_feature_names) + ord_col + num_col

support_mask = grid.best_estimator_.named_steps['feature_selection'].get_support()

selected_features = np.array(all_features)[support_mask]

print("🔝 Выбранные признаки (SelectKBest):")
for f in selected_features:
    print("•", f)

coefficients = grid.best_estimator_.named_steps['models'].coef_[0]

importances = pd.Series(abs(coefficients), index=selected_features).sort_values(key=abs, ascending=False)

print("\n📊 Важность выбранных признаков:")
print(importances)

importances.plot(kind='barh')
plt.title("Коэффициенты логистической регрессии (топ 5 признаков)")
plt.xlabel("Коэффициент")
plt.gca().invert_yaxis()
plt.tight_layout()
plt.show()
# Out:
# 🔝 Выбранные признаки (SelectKBest):
# • weight_class
# • price
# • prior_purchases
# • discount
# • weight
#
# 📊 Важность выбранных признаков:
# discount           6.785974
# weight             0.817116
# prior_purchases    0.646988
# price              0.545206
# weight_class       0.152675
# dtype: float64

# %% [markdown]
# ## 🧪 Уточнение логистической регрессии с регуляризацией

# %%
pipe_regularized = Pipeline([
    ('preprocessor', data_preprocessor),
    ('feature_selection', SelectKBest(score_func=f_classif, k=5)),
    ('model', LogisticRegression(solver='saga', max_iter=10000, random_state=42))
])

param_grid_reg = [
    {
        'model__penalty': ['l1'],
        'model__C': np.logspace(-2, 2, 10),
    },
    {
        'model__penalty': ['l2'],
        'model__C': np.logspace(-2, 2, 10),
    },
    {
        'model__penalty': ['elasticnet'],
        'model__C': np.logspace(-2, 2, 10),
        'model__l1_ratio': [0.1, 0.5, 0.9],
    }
]

# %% [markdown]
# ## 🤖 Подбор модели с кросс-валидацией и GridSearch

# %%
grid_lr = GridSearchCV(
    pipe_regularized,
    param_grid_reg,
    cv=5,
    scoring='recall',
    n_jobs=-1,
    verbose=2
)
grid_lr.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 50 candidates, totalling 250 fits
# [CV] END feature_selection__k=5, models=<catboost.core.CatBoostClassifier object at 0x113377a10>, models__depth=4, models__iterations=100, models__learning_rate=0.1; total time=   0.2s
# [CV] END feature_selection__k=5, models=<catboost.core.CatBoostClassifier object at 0x114e57c50>, models__depth=4, models__iterations=200, models__learning_rate=0.1; total time=   0.4s
# [CV] END feature_selection__k=5, models=<catboost.core.CatBoostClassifier object at 0x114ea2fd0>, models__depth=8, models__iterations=100, models__learning_rate=0.03; total time=   0.2s
# [CV] END feature_selection__k=5, models=<catboost.core.CatBoostClassifier object at 0x114eee470>, models__depth=8, models__iterations=100, models__learning_rate=0.1; total time=   0.2s
# [CV] END feature_selection__k=5, models=<catboost.core.CatBoostClassifier object at 0x101307d50>, models__depth=8, models__iterations=200, models__learning_rate=0.03; total time=   0.5s
# [CV] END feature_selection__k=10, models=<catboost.core.CatBoostClassifier object at 0x114fd05f0>, models__depth=4, models__iterations=100, models__learning_rate=0.1; total time=   0.1s
# [CV] END feature_selection__k=10, models=<catboost.core.CatBoostClassifier object at 0x114f99ef0>, models__depth=4, models__iterations=100, models__learning_rate=0.1; total time=   0.1s
# [CV] END feature_selection__k=10, models=<catboost.core.CatBoostClassifier object at 0x114fe4ae0>, models__depth=4, models__iterations=200, models__learning_rate=0.03; total time=   0.3s
# [CV] END feature_selection__k=10, models=<catboost.core.CatBoostClassifier object at 0x114f4d010>, models__depth=6, models__iterations=100, models__learning_rate=0.03; total time=   0.1s
# [CV] END feature_selection__k=10, models=<catboost.core.CatBoostClassifier object at 0x114efb960>, models__depth=6, models__iterations=100, models__learning_rate=0.1; total time=   0.2s
# [CV] END feature_selection__k=10, models=<catboost.core.CatBoostClassifier object at 0x114fa68f0>, models__depth=6, models__iterations=200, models__learning_rate=0.03; total time=   0.4s
# [CV] END feature_selection__k=10, models=<catboost.core.CatBoostClassifier object at 0x1136cccb0>, models__depth=8, models__iterations=100, models__learning_rate=0.1; total time=   0.3s
# [CV] END feature_selection__k=10, models=<catboost.core.CatBoostClassifier object at 0x1136cccb0>, models__depth=8, models__iterations=200, models__learning_rate=0.1; total time=   0.7s
# [CV] END feature_selection__k=all, models=<catboost.core.CatBoostClassifier object at 0x1136cccb0>, models__depth=4, models__iterations=200, models__learning_rate=0.1; total time=   0.3s
# [CV] END feature_selection__k=all, models=<catboost.core.CatBoostClassifier object at 0x1136cccb0>, models__depth=6, models__iterations=100, models__learning_rate=0.1; total time=   0.1s
# [CV] END feature_selection__k=all, models=<catboost.core.CatBoostClassifier object at 0x1136cccb0>, models__depth=6, models__iterations=200, models__learning_rate=0.1; total time=   0.5s
# [CV] END feature_selection__k=all, models=<catboost.core.CatBoostClassifier object at 0x1136cccb0>, models__depth=8, models__iterations=100, models__learning_rate=0.1; total time=   0.3s
# [CV] END feature_selection__k=all, models=<catboost.core.CatBoostClassifier object at 0x1136cccb0>, models__depth=8, models__iterations=200, models__learning_rate=0.1; total time=   1.0s
# [CV] END feature_selection__k=5, models=LGBMClassifier(verbose=-1), models__learning_rate=0.05, models__max_depth=10, models__n_estimators=100; total time=   2.2s
# [CV] END feature_selection__k=5, models=LGBMClassifier(verbose=-1), models__learning_rate=0.1, models__max_depth=5, models__n_estimators=200; total time=   2.1s
# [CV] END feature_selection__k=5, models=LGBMClassifier(verbose=-1), models__learning_rate=0.1, models__max_depth=10, models__n_estimators=200; total time=   4.1s
# [CV] END feature_selection__k=10, models=LGBMClassifier(verbose=-1), models__learning_rate=0.1, models__max_depth=5, models__n_estimators=100; total time=   1.1s
# [CV] END feature_selection__k=10, models=LGBMClassifier(verbose=-1), models__learning_rate=0.1, models__max_depth=5, models__n_estimators=200; total time=   2.3s
# [CV] END feature_selection__k=all, models=LGBMClassifier(verbose=-1), models__learning_rate=0.05, models__max_depth=5, models__n_estimators=100; total time=   1.0s
# [CV] END feature_selection__k=all, models=LGBMClassifier(verbose=-1), models__learning_rate=0.05, models__max_depth=10, models__n_estimators=100; total time=   2.0s
# [CV] END feature_selection__k=all, models=LGBMClassifier(verbose=-1), models__learning_rate=0.05, models__max_depth=10, models__n_estimators=200; total time=   3.5s
# [CV] END feature_selection__k=5, models=LogisticRegression(random_state=42, solver='liblinear'), models__C=1, preprocessor__num__scaler=StandardScaler(); total time=   0.1s
# [CV] END feature_selection__k=5, models=LogisticRegression(random_state=42, solver='liblinear'), models__C=1, preprocessor__num__scaler=MinMaxScaler(); total time=   0.1s
# [CV] END feature_selection__k=5, models=LogisticRegression(random_state=42, solver='liblinear'), models__C=2, preprocessor__num__scaler=StandardScaler(); total time=   0.0s
# [CV] END feature_selection__k=5, models=LogisticRegression(random_state=42, solver='liblinear'), models__C=2, preprocessor__num__scaler=MinMaxScaler(); total time=   0.1s
# [CV] END feature_selection__k=5, models=LogisticRegression(random_state=42, solver='liblinear'), models__C=3, preprocessor__num__scaler=StandardScaler(); total time=   0.1s
# [CV] END feature_selection__k=5, models=LogisticRegression(random_state=42, solver='liblinear'), models__C=3, preprocessor__num__scaler=MinMaxScaler(); total time=   0.1s
# [CV] END feature_selection__k=5, models=LogisticRegression(random_state=42, solver='liblinear'), models__C=4, preprocessor__num__scaler=StandardScaler(); total time=   0.0s
# [CV] END feature_selection__k=5, models=LogisticRegression(random_state=42, solver='liblinear'), models__C=5, preprocessor__num__scaler=StandardScaler(); total time=   0.0s
# [CV] END feature_selection__k=5, models=LogisticRegression(random_state=42, solver='liblinear'), models__C=5, preprocessor__num__scaler=MinMaxScaler(); total time=   0.0s
# [CV] END feature_selection__k=5, models=LogisticRegression(random_state=42, solver='liblinear'), models__C=6, preprocessor__num__scaler=MinMaxScaler(); total time=   0.0s
# [CV] END feature_selection__k=5, models=LogisticRegression(random_state=42, solver='liblinear'), models__C=7, preprocessor__num__scaler=StandardScaler(); total time=   0.0s
# [CV] END feature_selection__k=5, models=LogisticRegression(random_state=42, solver='liblinear'), models__C=9, preprocessor__num__scaler=StandardScaler(); total time=   0.0s
# [CV] END feature_selection__k=5, models=LogisticRegression(random_state=42, solver='liblinear'), models__C=10, preprocessor__num__scaler=StandardScaler(); total time=   0.0s
# [CV] END feature_selection__k=5, models=LogisticRegression(random_state=42, solver='liblinear'), models__C=10, preprocessor__num__scaler=MinMaxScaler(); total time=   0.0s
# [CV] END feature_selection__k=5, models=LogisticRegression(random_state=42, solver='liblinear'), models__C=11, preprocessor__num__scaler=MinMaxScaler(); total time=   0.0s
# [CV] END feature_selection__k=5, models=LogisticRegression(random_state=42, solver='liblinear'), models__C=11, preprocessor__num__scaler=MinMaxScaler(); total time=   0.0s
# [CV] END feature_selection__k=5, models=LogisticRegression(random_state=42, solver='liblinear'), models__C=13, preprocessor__num__scaler=StandardScaler(); total time=   0.0s
# [CV] END feature_selection__k=5, models=LogisticRegression(random_state=42, solver='liblinear'), models__C=13, preprocessor__num__scaler=MinMaxScaler(); total time=   0.0s
# [CV] END feature_selection__k=10, models=LogisticRegression(random_state=42, solver='liblinear'), models__C=2, preprocessor__num__scaler=StandardScaler(); total time=   0.0s
# [CV] END feature_selection__k=10, models=LogisticRegression(random_state=42, solver='liblinear'), models__C=2, preprocessor__num__scaler=MinMaxScaler(); total time=   0.0s
# [CV] END feature_selection__k=10, models=LogisticRegression(random_state=42, solver='liblinear'), models__C=2, preprocessor__num__scaler=MinMaxScaler(); total time=   0.0s[CV] END feature_selection__k=5, models=<catboost.core.CatBoostClassifier object at 0x151427a10>, models__depth=4, models__iterations=200, models__learning_rate=0.03; total time=   0.4s
# [CV] END feature_selection__k=5, models=<catboost.core.CatBoostClassifier object at 0x152e57c50>, models__depth=6, models__iterations=100, models__learning_rate=0.1; total time=   0.2s
# [CV] END feature_selection__k=5, models=<catboost.core.CatBoostClassifier object at 0x152ea2fd0>, models__depth=8, models__iterations=100, models__learning_rate=0.03; total time=   0.2s
# [CV] END feature_selection__k=5, models=<catboost.core.CatBoostClassifier object at 0x152eee470>, models__depth=8, models__iterations=100, models__learning_rate=0.03; total time=   0.2s
# [CV] END feature_selection__k=5, models=<catboost.core.CatBoostClassifier object at 0x10635bd50>, models__depth=8, models__iterations=100, models__learning_rate=0.1; total time=   0.2s
# [CV] END feature_selection__k=5, models=<catboost.core.CatBoostClassifier object at 0x152fd05f0>, models__depth=8, models__iterations=200, models__learning_rate=0.1; total time=   0.6s
# [CV] END feature_selection__k=10, models=<catboost.core.CatBoostClassifier object at 0x152f99ef0>, models__depth=4, models__iterations=200, models__learning_rate=0.1; total time=   0.3s
# [CV] END feature_selection__k=10, models=<catboost.core.CatBoostClassifier object at 0x152fc0ae0>, models__depth=6, models__iterations=100, models__learning_rate=0.03; total time=   0.2s
# [CV] END feature_selection__k=10, models=<catboost.core.CatBoostClassifier object at 0x152f49010>, models__depth=6, models__iterations=100, models__learning_rate=0.1; total time=   0.2s
# [CV] END feature_selection__k=10, models=<catboost.core.CatBoostClassifier object at 0x152efb960>, models__depth=6, models__iterations=200, models__learning_rate=0.1; total time=   0.4s
# [CV] END feature_selection__k=10, models=<catboost.core.CatBoostClassifier object at 0x152fa68f0>, models__depth=8, models__iterations=200, models__learning_rate=0.03; total time=   0.7s
# [CV] END feature_selection__k=all, models=<catboost.core.CatBoostClassifier object at 0x1517c0cb0>, models__depth=4, models__iterations=100, models__learning_rate=0.03; total time=   0.1s
# [CV] END feature_selection__k=all, models=<catboost.core.CatBoostClassifier object at 0x1517c0cb0>, models__depth=4, models__iterations=100, models__learning_rate=0.1; total time=   0.1s
# [CV] END feature_selection__k=all, models=<catboost.core.CatBoostClassifier object at 0x1517c0cb0>, models__depth=4, models__iterations=200, models__learning_rate=0.1; total time=   0.4s
# [CV] END feature_selection__k=all, models=<catboost.core.CatBoostClassifier object at 0x1517c0cb0>, models__depth=6, models__iterations=100, models__learning_rate=0.1; total time=   0.1s
# [CV] END feature_selection__k=all, models=<catboost.core.CatBoostClassifier object at 0x1517c0cb0>, models__depth=6, models__iterations=200, models__learning_rate=0.1; total time=   0.4s
# [CV] END feature_selection__k=all, models=<catboost.core.CatBoostClassifier object at 0x1517c0cb0>, models__depth=8, models__iterations=100, models__learning_rate=0.1; total time=   0.3s
# [CV] END feature_selection__k=all, models=<catboost.core.CatBoostClassifier object at 0x1517c0cb0>, models__depth=8, models__iterations=200, models__learning_rate=0.03; total time=   1.0s
# [CV] END feature_selection__k=5, models=LGBMClassifier(verbose=-1), models__learning_rate=0.05, models__max_depth=10, models__n_estimators=100; total time=   2.2s
# [CV] END feature_selection__k=5, models=LGBMClassifier(verbose=-1), models__learning_rate=0.1, models__max_depth=5, models__n_estimators=100; total time=   1.2s
# [CV] END feature_selection__k=5, models=LGBMClassifier(verbose=-1), models__learning_rate=0.1, models__max_depth=10, models__n_estimators=100; total time=   1.9s
# [CV] END feature_selection__k=10, models=LGBMClassifier(verbose=-1), models__learning_rate=0.05, models__max_depth=5, models__n_estimators=100; total time=   1.0s
# [CV] END feature_selection__k=10, models=LGBMClassifier(verbose=-1), models__learning_rate=0.05, models__max_depth=10, models__n_estimators=100; total time=   2.1s
# [CV] END feature_selection__k=10, models=LGBMClassifier(verbose=-1), models__learning_rate=0.1, models__max_depth=5, models__n_estimators=100; total time=   1.2s
# [CV] END feature_selection__k=10, models=LGBMClassifier(verbose=-1), models__learning_rate=0.1, models__max_depth=5, models__n_estimators=200; total time=   2.0s
# [CV] END feature_selection__k=10, models=LGBMClassifier(verbose=-1), models__learning_rate=0.1, models__max_depth=10, models__n_estimators=200; total time=   3.7s
# [CV] END feature_selection__k=all, models=LGBMClassifier(verbose=-1), models__learning_rate=0.1, models__max_depth=5, models__n_estimators=200; total time=   1.8s
# [CV] END feature_selection__k=all, models=LGBMClassifier(verbose=-1), models__learning_rate=0.1, models__max_depth=10, models__n_estimators=100; total time=   1.5s
# [CV] END feature_selection__k=5, models=LogisticRegression(random_state=42, solver='liblinear'), models__C=4, preprocessor__num__scaler=MinMaxScaler(); total time=   0.0s
# [CV] END feature_selection__k=5, models=LogisticRegression(random_state=42, solver='liblinear'), models__C=5, preprocessor__num__scaler=StandardScaler(); total time=   0.0s
# [CV] END feature_selection__k=5, models=LogisticRegression(random_state=42, solver='liblinear'), models__C=6, preprocessor__num__scaler=StandardScaler(); total time=   0.0s
# [CV] END feature_selection__k=5, models=LogisticRegression(random_state=42, solver='liblinear'), models__C=6, preprocessor__num__scaler=MinMaxScaler(); total time=   0.0s
# [CV] END feature_selection__k=5, models=LogisticRegression(random_state=42, solver='liblinear'), models__C=7, preprocessor__num__scaler=MinMaxScaler(); total time=   0.0s
# [CV] END feature_selection__k=5, models=LogisticRegression(random_state=42, solver='liblinear'), models__C=8, preprocessor__num__scaler=MinMaxScaler(); total time=   0.0s
# [CV] END feature_selection__k=5, models=LogisticRegression(random_state=42, solver='liblinear'), models__C=9, preprocessor__num__scaler=StandardScaler(); total time=   0.0s
# [CV] END feature_selection__k=5, models=LogisticRegression(random_state=42, solver='liblinear'), models__C=11, preprocessor__num__scaler=StandardScaler(); total time=   0.0s
# [CV] END feature_selection__k=5, models=LogisticRegression(random_state=42, solver='liblinear'), models__C=11, preprocessor__num__scaler=StandardScaler(); total time=   0.0s
# [CV] END feature_selection__k=5, models=LogisticRegression(random_state=42, solver='liblinear'), models__C=12, preprocessor__num__scaler=StandardScaler(); total time=   0.0s
# [CV] END feature_selection__k=5, models=LogisticRegression(random_state=42, solver='liblinear'), models__C=12, preprocessor__num__scaler=MinMaxScaler(); total time=   0.0s
# [CV] END feature_selection__k=5, models=LogisticRegression(random_state=42, solver='liblinear'), models__C=14, preprocessor__num__scaler=StandardScaler(); total time=   0.0s
# [CV] END feature_selection__k=5, models=LogisticRegression(random_state=42, solver='liblinear'), models__C=14, preprocessor__num__scaler=StandardScaler(); total time=   0.0s
# [CV] END feature_selection__k=10, models=LogisticRegression(random_state=42, solver='liblinear'), models__C=1, preprocessor__num__scaler=StandardScaler(); total time=   0.0s
# [CV] END feature_selection__k=10, models=LogisticRegression(random_state=42, solver='liblinear'), models__C=1, preprocessor__num__scaler=StandardScaler(); total time=   0.0s
# [CV] END feature_selection__k=10, models=LogisticRegression(random_state=42, solver='liblinear'), models__C=1, preprocessor__num__scaler=StandardScaler(); total time=   0.0s
# [CV] END feature_selection__k=10, models=LogisticRegression(random_state=42, solver='liblinear'), models__C=1, preprocessor__num__scaler=MinMaxScaler(); total time=   0.0s
# [CV] END feature_selection__k=10, models=LogisticRegression(random_state=42, solver='liblinear'), models__C=6, preprocessor__num__scaler=StandardScaler(); total time=   0.0s
# [CV] END feature_selection__k=10, models=LogisticRegression(random_state=42, solver='liblinear'), models__C=6, preprocessor__num__scaler=MinMaxScaler(); total time=   0.0s
# GridSearchCV(cv=5,
#              estimator=Pipeline(steps=[('preprocessor',
#                                         ColumnTransformer(transformers=[('ohe',
#                                                                          Pipeline(steps=[('imputer',
#                                                                                           SimpleImputer(strategy='most_frequent')),
#                                                                                          ('ohe',
#                                                                                           OneHotEncoder(drop='first',
#                                                                                                         handle_unknown='ignore',
#                                                                                                         sparse_output=False))]),
#                                                                          ['gender',
#                                                                           'mode_of_shipment']),
#                                                                         ('ord',
#                                                                          Pipeline(steps=[('imputer1',
#                                                                                           SimpleImputer(strategy='most_freque...
#        5.99484250e-01, 1.66810054e+00, 4.64158883e+00, 1.29154967e+01,
#        3.59381366e+01, 1.00000000e+02]),
#                           'model__penalty': ['l2']},
#                          {'model__C': array([1.00000000e-02, 2.78255940e-02, 7.74263683e-02, 2.15443469e-01,
#        5.99484250e-01, 1.66810054e+00, 4.64158883e+00, 1.29154967e+01,
#        3.59381366e+01, 1.00000000e+02]),
#                           'model__l1_ratio': [0.1, 0.5, 0.9],
#                           'model__penalty': ['elasticnet']}],
#              scoring='recall', verbose=2)

# %%
print("Best recall (CV):", grid_lr.best_score_)
print("Best params:", grid_lr.best_params_)
# Out:
# Best recall (CV): 0.7024761904761905
# Best params: {'model__C': np.float64(0.01), 'model__penalty': 'l1'}

# %%
y_proba = grid_lr.predict_proba(X_test)[:, 1]
thresholds = np.arange(0.0, 1.01, 0.01)
results = []

for thresh in thresholds:
    y_pred = (y_proba >= thresh).astype(int)
    recall = recall_score(y_test, y_pred)
    precision = precision_score(y_test, y_pred)
    results.append((thresh, recall, precision))

df_metrics = pd.DataFrame(results, columns=['threshold', 'recall', 'precision'])
# Out:
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %%
df_filtered = df_metrics[df_metrics['recall'] >= 0.75]

best_row = df_filtered.loc[df_filtered['precision'].idxmax()]
print("Лучший порог:", best_row)
# Out:
# Лучший порог: threshold    0.470000
# recall       0.776085
# precision    0.662549
# Name: 47, dtype: float64

# %% [markdown]
# ## 🎯 Оптимизация порога классификации

# %%
y_test_proba = grid_lr.predict_proba(X_test)[:, 1]

threshold = 0.47
y_test_pred = (y_test_proba >= threshold).astype(int)

# %%
recall = recall_score(y_test, y_test_pred)
precision = precision_score(y_test, y_test_pred)

print(f"Recall на тесте: {recall:.4f}")
print(f"Precision на тесте: {precision:.4f}")

cm = confusion_matrix(y_test, y_test_pred)

disp = ConfusionMatrixDisplay(confusion_matrix=cm)
disp.plot(
    cmap=plt.cm.Blues,
    colorbar=True,
    values_format='d'
)
plt.title("Матрица ошибок с адаптированным порогом")
plt.tight_layout()
plt.show()
# Out:
# Recall на тесте: 0.7761
# Precision на тесте: 0.6625

# %% [markdown]
# ## 📈 PR-кривая и ROC-кривая

# %%
y_proba = grid_lr.best_estimator_.predict_proba(X_test)[:, 1]

precision, recall, thresholds_pr = precision_recall_curve(y_test, y_proba)
pr_auc = auc(recall, precision)

plt.figure(figsize=(8, 6))
plt.plot(recall, precision, label=f'PR curve (AUC = {pr_auc:.4f})')
plt.xlabel("Recall")
plt.ylabel("Precision")
plt.title("Precision-Recall Curve")
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()

fpr, tpr, thresholds_roc = roc_curve(y_test, y_proba)
roc_auc = auc(fpr, tpr)

plt.figure(figsize=(8, 6))
plt.plot(fpr, tpr, label=f'ROC curve (AUC = {roc_auc:.4f})')
plt.plot([0, 1], [0, 1], 'k--', alpha=0.5)
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate (Recall)")
plt.title("ROC Curve")
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()
# Out:
# [CV] END feature_selection__k=5, models=<catboost.core.CatBoostClassifier object at 0x10e3dba10>, models__depth=4, models__iterations=200, models__learning_rate=0.03; total time=   0.4s
# [CV] END feature_selection__k=5, models=<catboost.core.CatBoostClassifier object at 0x10fe77c50>, models__depth=6, models__iterations=100, models__learning_rate=0.1; total time=   0.2s
# [CV] END feature_selection__k=5, models=<catboost.core.CatBoostClassifier object at 0x10fec2fd0>, models__depth=6, models__iterations=200, models__learning_rate=0.1; total time=   0.8s
# [CV] END feature_selection__k=10, models=<catboost.core.CatBoostClassifier object at 0x10ff0e470>, models__depth=4, models__iterations=100, models__learning_rate=0.03; total time=   0.2s
# [CV] END feature_selection__k=10, models=<catboost.core.CatBoostClassifier object at 0x10474bd50>, models__depth=4, models__iterations=100, models__learning_rate=0.03; total time=   0.2s
# [CV] END feature_selection__k=10, models=<catboost.core.CatBoostClassifier object at 0x11a4945f0>, models__depth=4, models__iterations=200, models__learning_rate=0.03; total time=   0.6s
# [CV] END feature_selection__k=10, models=<catboost.core.CatBoostClassifier object at 0x11a449ef0>, models__depth=6, models__iterations=100, models__learning_rate=0.1; total time=   0.1s
# [CV] END feature_selection__k=10, models=<catboost.core.CatBoostClassifier object at 0x11a490ae0>, models__depth=8, models__iterations=100, models__learning_rate=0.03; total time=   0.3s
# [CV] END feature_selection__k=10, models=<catboost.core.CatBoostClassifier object at 0x11a3f9010>, models__depth=8, models__iterations=100, models__learning_rate=0.1; total time=   0.3s
# [CV] END feature_selection__k=10, models=<catboost.core.CatBoostClassifier object at 0x10ff1b960>, models__depth=8, models__iterations=200, models__learning_rate=0.03; total time=   0.6s
# [CV] END feature_selection__k=all, models=<catboost.core.CatBoostClassifier object at 0x11a4568f0>, models__depth=4, models__iterations=100, models__learning_rate=0.1; total time=   0.1s
# [CV] END feature_selection__k=all, models=<catboost.core.CatBoostClassifier object at 0x10e79ccb0>, models__depth=4, models__iterations=200, models__learning_rate=0.1; total time=   0.3s
# [CV] END feature_selection__k=all, models=<catboost.core.CatBoostClassifier object at 0x10e79ccb0>, models__depth=6, models__iterations=100, models__learning_rate=0.1; total time=   0.1s
# [CV] END feature_selection__k=all, models=<catboost.core.CatBoostClassifier object at 0x10e79ccb0>, models__depth=6, models__iterations=200, models__learning_rate=0.1; total time=   0.5s
# [CV] END feature_selection__k=all, models=<catboost.core.CatBoostClassifier object at 0x10e79ccb0>, models__depth=8, models__iterations=100, models__learning_rate=0.1; total time=   0.3s
# [CV] END feature_selection__k=all, models=<catboost.core.CatBoostClassifier object at 0x10e79ccb0>, models__depth=8, models__iterations=200, models__learning_rate=0.1; total time=   0.8s
# [CV] END feature_selection__k=5, models=LGBMClassifier(verbose=-1), models__learning_rate=0.05, models__max_depth=5, models__n_estimators=200; total time=   2.1s
# [CV] END feature_selection__k=5, models=LGBMClassifier(verbose=-1), models__learning_rate=0.1, models__max_depth=5, models__n_estimators=100; total time=   1.1s
# [CV] END feature_selection__k=5, models=LGBMClassifier(verbose=-1), models__learning_rate=0.1, models__max_depth=5, models__n_estimators=200; total time=   2.0s
# [CV] END feature_selection__k=10, models=LGBMClassifier(verbose=-1), models__learning_rate=0.05, models__max_depth=5, models__n_estimators=100; total time=   1.1s
# [CV] END feature_selection__k=10, models=LGBMClassifier(verbose=-1), models__learning_rate=0.05, models__max_depth=5, models__n_estimators=200; total time=   2.4s
# [CV] END feature_selection__k=10, models=LGBMClassifier(verbose=-1), models__learning_rate=0.05, models__max_depth=10, models__n_estimators=200; total time=   3.7s
# [CV] END feature_selection__k=all, models=LGBMClassifier(verbose=-1), models__learning_rate=0.05, models__max_depth=5, models__n_estimators=100; total time=   1.1s
# [CV] END feature_selection__k=all, models=LGBMClassifier(verbose=-1), models__learning_rate=0.05, models__max_depth=10, models__n_estimators=100; total time=   2.0s
# [CV] END feature_selection__k=all, models=LGBMClassifier(verbose=-1), models__learning_rate=0.05, models__max_depth=10, models__n_estimators=200; total time=   4.0s
# [CV] END feature_selection__k=5, models=LogisticRegression(random_state=42, solver='liblinear'), models__C=5, preprocessor__num__scaler=StandardScaler(); total time=   0.0s
# [CV] END feature_selection__k=5, models=LogisticRegression(random_state=42, solver='liblinear'), models__C=5, preprocessor__num__scaler=MinMaxScaler(); total time=   0.0s
# [CV] END feature_selection__k=5, models=LogisticRegression(random_state=42, solver='liblinear'), models__C=6, preprocessor__num__scaler=MinMaxScaler(); total time=   0.0s
# [CV] END feature_selection__k=5, models=LogisticRegression(random_state=42, solver='liblinear'), models__C=7, preprocessor__num__scaler=MinMaxScaler(); total time=   0.0s
# [CV] END feature_selection__k=5, models=LogisticRegression(random_state=42, solver='liblinear'), models__C=8, preprocessor__num__scaler=StandardScaler(); total time=   0.0s
# [CV] END feature_selection__k=5, models=LogisticRegression(random_state=42, solver='liblinear'), models__C=8, preprocessor__num__scaler=MinMaxScaler(); total time=   0.0s
# [CV] END feature_selection__k=5, models=LogisticRegression(random_state=42, solver='liblinear'), models__C=9, preprocessor__num__scaler=StandardScaler(); total time=   0.0s
# [CV] END feature_selection__k=5, models=LogisticRegression(random_state=42, solver='liblinear'), models__C=10, preprocessor__num__scaler=MinMaxScaler(); total time=   0.0s
# [CV] END feature_selection__k=5, models=LogisticRegression(random_state=42, solver='liblinear'), models__C=10, preprocessor__num__scaler=MinMaxScaler(); total time=   0.0s
# [CV] END feature_selection__k=5, models=LogisticRegression(random_state=42, solver='liblinear'), models__C=12, preprocessor__num__scaler=StandardScaler(); total time=   0.0s
# [CV] END feature_selection__k=5, models=LogisticRegression(random_state=42, solver='liblinear'), models__C=12, preprocessor__num__scaler=StandardScaler(); total time=   0.0s
# [CV] END feature_selection__k=5, models=LogisticRegression(random_state=42, solver='liblinear'), models__C=13, preprocessor__num__scaler=MinMaxScaler(); total time=   0.0s
# [CV] END feature_selection__k=5, models=LogisticRegression(random_state=42, solver='liblinear'), models__C=13, preprocessor__num__scaler=MinMaxScaler(); total time=   0.0s
# [CV] END feature_selection__k=5, models=LogisticRegression(random_state=42, solver='liblinear'), models__C=14, preprocessor__num__scaler=MinMaxScaler(); total time=   0.0s
# [CV] END feature_selection__k=5, models=LogisticRegression(random_state=42, solver='liblinear'), models__C=14, preprocessor__num__scaler=MinMaxScaler(); total time=   0.0s
# [CV] END feature_selection__k=10, models=LogisticRegression(random_state=42, solver='liblinear'), models__C=3, preprocessor__num__scaler=MinMaxScaler(); total time=   0.1s
# [CV] END feature_selection__k=10, models=LogisticRegression(random_state=42, solver='liblinear'), models__C=3, preprocessor__num__scaler=MinMaxScaler(); total time=   0.0s
# [CV] END feature_selection__k=10, models=LogisticRegression(random_state=42, solver='liblinear'), models__C=4, preprocessor__num__scaler=StandardScaler(); total time=   0.0s
# [CV] END feature_selection__k=10, models=LogisticRegression(random_state=42, solver='liblinear'), models__C=4, preprocessor__num__scaler=StandardScaler(); total time=   0.0s
# [CV] END feature_selection__k=10, models=LogisticRegression(random_state=42, solver='liblinear'), models__C=7, preprocessor__num__scaler=StandardScaler(); total time=   0.0s
# [CV] END feature_selection__k=10, models=LogisticRegression(random_state=42, solver='liblinear'), models__C=7, preprocessor__num__scaler=StandardScaler(); total time=   0.0s
# [CV] END feature_selection__k=10, models=LogisticRegression(random_state=42, solver='liblinear'), models__C=7, preprocessor__num__scaler=StandardScaler(); total time=   0.0s
# [CV] END feature_selection__k=10, models=LogisticRegression(random_state=42, solver='liblinear'), models__C=7, preprocessor__num__scaler=MinMaxScaler(); total time=   0.0s
# [CV] END feature_selection__k=10, models=LogisticRegression(random_state=42, solver='liblinear'), models__C=10, preprocessor__num__scaler=StandardScaler(); total time=   0.0s
# [CV] END feature_selection__k=10, models=LogisticRegression(random_state=42, solver='liblinear'), models__C=10, preprocessor__num__scaler=MinMaxScaler(); total time=   0.0s
# [CV] END feature_selection__k=10, models=LogisticRegression(random_state=42, solver='liblinear'), models__C=10, preprocessor__num__scaler=MinMaxScaler(); total time=   0.0s
# [CV] END feature_selection__k=10, models=LogisticRegression(random_state=42, solver='liblinear'), models__C=10, preprocessor__num__scaler=MinMaxScaler(); total time=   0.0s
# [CV] END feature_selection__k=10, models=LogisticRegression(random_state=42, solver='liblinear'), models__C=13, preprocessor__num__scaler=StandardScaler(); total time=   0.0s
# [CV] END feature_selection__k=10, models=LogisticRegression(random_state=42, solver='liblinear'), models__C=13, preprocessor__num__scaler=StandardScaler(); total time=   0.1s
# [CV] END feature_selection__k=10, models=LogisticRegression(random_state=42, solver='liblinear'), models__C=13, preprocessor__num__scaler=StandardScaler(); total time=   0.0s
# [CV] END feature_selection__k=10, models=LogisticRegression(random_state=42, solver='liblinear'), models__C=13, preprocessor__num__scaler=MinMaxScaler(); total time=   0.0s
# [CV] END feature_selection__k=all, models=LogisticRegression(random_state=42, solver='liblinear'), models__C=4, preprocessor__num__scaler=StandardScaler(); total time=   0.0s
# [CV] END feature_selection__k=all, models=LogisticRegression(random_state=42, solver='liblinear'), models__C=4, preprocessor__num__scaler=MinMaxScaler(); total time=   0.0s
# [CV] END feature_selection__k=all, models=LogisticRegression(random_state=42, solver='liblinear'), models__C=4, preprocessor__num__scaler=MinMaxScaler(); total time=   0.0s
# [CV] END feature_selection__k=all, models=LogisticRegression(random_state=42, solver='liblinear'), models__C=4, preprocessor__num__scaler=MinMaxScaler(); total time=   0.0s
# [CV] END feature_selection__k=all, models=LogisticRegression(random_state=42, solver='liblinear'), models__C=12, preprocessor__num__scaler=StandardScaler(); total time=   0.0s
# [CV] END feature_selection__k=all, models=LogisticRegression(random_state=42, solver='liblinear'), models__C=12, preprocessor__num__scaler=MinMaxScaler(); total time=   0.0s
# [CV] END feature_selection__k=all, models=LogisticRegression(random_state=42, solver='liblinear'), models__C=12, preprocessor__num__scaler=MinMaxScaler(); total time=   0.0s
# [CV] END feature_selection__k=all, models=LogisticRegression(random_state=42, solver='liblinear'), models__C=12, preprocessor__num__scaler=MinMaxScaler(); total time=   0.0s
# [CV] END feature_selection__k=5, models=RandomForestClassifier(random_state=42), models__max_depth=10, models__min_samples_split=2, models__n_estimators=200; total time=   1.1s
# [CV] END feature_selection__k=5, models=RandomForestClassifier(random_state=42), models__max_depth=10, models__min_samples_split=2, models__n_estimators=200; total time=   1.1s
# [CV] END feature_selection__k=5, models=RandomForestClassifier(random_state=42), models__max_depth=10, models__min_samples_split=5, models__n_estimators=100; total time=   0.6s
# [CV] END feature_selection__k=5, models=RandomForestClassifier(random_state=42), models__max_depth=10, models__min_samples_split=5, models__n_estimators=100; total time=   0.5s
# [CV] END feature_selection__k=all, models=RandomForestClassifier(random_state=42), models__max_depth=5, models__min_samples_split=5, models__n_estimators=100; total time=   0.3s
# [CV] END feature_selection__k=all, models=RandomForestClassifier(random_state=42), models__max_depth=5, models__min_samples_split=5, models__n_estimators=200; total time=   0.7s
# [CV] END feature_selection__k=all, models=RandomForestClassifier(random_state=42), models__max_depth=10, models__min_samples_split=2, models__n_estimators=100; total time=   0.5s
# [CV] END feature_selection__k=all, models=RandomForestClassifier(random_state=42), models__max_depth=10, models__min_samples_split=5, models__n_estimators=100; total time=   0.5s
# [CV] END feature_selection__k=all, models=RandomForestClassifier(random_state=42), models__max_depth=10, models__min_samples_split=5, models__n_estimators=200; total time=   0.8s
# [CV] END ...................model__C=0.01, model__penalty=l1; total time=   0.0s
# [CV] END ...model__C=0.027825594022071243, model__penalty=l1; total time=   0.0s
# [CV] END ....model__C=0.21544346900318834, model__penalty=l1; total time=   0.1s
# [CV] END ....model__C=0.21544346900318834, model__penalty=l1; total time=   0.1s
# [CV] END .....model__C=4.6415888336127775, model__penalty=l1; total time=   0.1s
# [CV] END .....model__C=12.915496650148826, model__penalty=l1; total time=   0.0s
# [CV] END .....model__C=1.6681005372000592, model__penalty=l2; total time=   0.0s
# [CV] END .....model__C=1.6681005372000592, model__penalty=l2; total time=   0.0s
# [CV] END .....model__C=1.6681005372000592, model__penalty=l2; total time=   0.1s
# [CV] END .....model__C=1.6681005372000592, model__penalty=l2; total time=   0.1s
# [CV] END model__C=0.01, model__l1_ratio=0.1, model__penalty=elasticnet; total time=   0.0s
# [CV] END model__C=0.01, model__l1_ratio=0.1, model__penalty=elasticnet; total time=   0.0s
# [CV] END model__C=0.01, model__l1_ratio=0.1, model__penalty=elasticnet; total time=   0.0s
# [CV] END model__C=0.01, model__l1_ratio=0.1, model__penalty=elasticnet; total time=   0.0s
# [CV] END model__C=0.0774263682681127, model__l1_ratio=0.1, model__penalty=elasticnet; total time=   0.0s
# [CV] END model__C=0.0774263682681127, model__l1_ratio=0.1, model__penalty=elasticnet; total time=   0.1s
# [CV] END model__C=0.0774263682681127, model__l1_ratio=0.1, model__penalty=elasticnet; total time=   0.0s
# [CV] END model__C=0.0774263682681127, model__l1_ratio=0.5, model__penalty=elasticnet; total time=   0.1s
# [CV] END model__C=0.5994842503189409, model__l1_ratio=0.1, model__penalty=elasticnet; total time=   0.1s
# [CV] END model__C=0.5994842503189409, model__l1_ratio=0.5, model__penalty=elasticnet; total time=   0.0s
# [CV] END model__C=0.5994842503189409, model__l1_ratio=0.5, model__penalty=elasticnet; total time=   0.1s
# [CV] END model__C=0.5994842503189409, model__l1_ratio=0.5, model__penalty=elasticnet; total time=   0.1s
# [CV] END model__C=4.6415888336127775, model__l1_ratio=0.5, model__penalty=elasticnet; total time=   0.1s
# [CV] END model__C=4.6415888336127775, model__l1_ratio=0.5, model__penalty=elasticnet; total time=   0.1s
# [CV] END model__C=4.6415888336127775, model__l1_ratio=0.5, model__penalty=elasticnet; total time=   0.1s
# [CV] END model__C=4.6415888336127775, model__l1_ratio=0.5, model__penalty=elasticnet; total time=   0.0s
# [CV] END model__C=35.93813663804626, model__l1_ratio=0.1, model__penalty=elasticnet; total time=   0.0s
# [CV] END model__C=35.93813663804626, model__l1_ratio=0.5, model__penalty=elasticnet; total time=   0.1s
# [CV] END model__C=35.93813663804626, model__l1_ratio=0.5, model__penalty=elasticnet; total time=   0.1s
# [CV] END model__C=35.93813663804626, model__l1_ratio=0.5, model__penalty=elasticnet; total time=   0.1s
#
# [CV] END feature_selection__k=10, models=LogisticRegression(random_state=42, solver='liblinear'), models__C=6, preprocessor__num__scaler=MinMaxScaler(); total time=   0.0s
# [CV] END feature_selection__k=10, models=LogisticRegression(random_state=42, solver='liblinear'), models__C=6, preprocessor__num__scaler=MinMaxScaler(); total time=   0.0s
# [CV] END feature_selection__k=10, models=LogisticRegression(random_state=42, solver='liblinear'), models__C=8, preprocessor__num__scaler=StandardScaler(); total time=   0.0s
# [CV] END feature_selection__k=10, models=LogisticRegression(random_state=42, solver='liblinear'), models__C=8, preprocessor__num__scaler=MinMaxScaler(); total time=   0.0s
# [CV] END feature_selection__k=10, models=LogisticRegression(random_state=42, solver='liblinear'), models__C=8, preprocessor__num__scaler=MinMaxScaler(); total time=   0.0s
# [CV] END feature_selection__k=10, models=LogisticRegression(random_state=42, solver='liblinear'), models__C=8, preprocessor__num__scaler=MinMaxScaler(); total time=   0.0s
# [CV] END feature_selection__k=10, models=LogisticRegression(random_state=42, solver='liblinear'), models__C=11, preprocessor__num__scaler=MinMaxScaler(); total time=   0.0s
# [CV] END feature_selection__k=10, models=LogisticRegression(random_state=42, solver='liblinear'), models__C=11, preprocessor__num__scaler=MinMaxScaler(); total time=   0.1s
# [CV] END feature_selection__k=10, models=LogisticRegression(random_state=42, solver='liblinear'), models__C=12, preprocessor__num__scaler=StandardScaler(); total time=   0.1s
# [CV] END feature_selection__k=10, models=LogisticRegression(random_state=42, solver='liblinear'), models__C=12, preprocessor__num__scaler=StandardScaler(); total time=   0.0s
# [CV] END feature_selection__k=all, models=LogisticRegression(random_state=42, solver='liblinear'), models__C=3, preprocessor__num__scaler=StandardScaler(); total time=   0.0s
# [CV] END feature_selection__k=all, models=LogisticRegression(random_state=42, solver='liblinear'), models__C=3, preprocessor__num__scaler=StandardScaler(); total time=   0.0s
# [CV] END feature_selection__k=all, models=LogisticRegression(random_state=42, solver='liblinear'), models__C=3, preprocessor__num__scaler=StandardScaler(); total time=   0.0s
# [CV] END feature_selection__k=all, models=LogisticRegression(random_state=42, solver='liblinear'), models__C=3, preprocessor__num__scaler=MinMaxScaler(); total time=   0.0s
# [CV] END feature_selection__k=all, models=LogisticRegression(random_state=42, solver='liblinear'), models__C=8, preprocessor__num__scaler=StandardScaler(); total time=   0.0s
# [CV] END feature_selection__k=all, models=LogisticRegression(random_state=42, solver='liblinear'), models__C=8, preprocessor__num__scaler=MinMaxScaler(); total time=   0.0s
# [CV] END feature_selection__k=all, models=LogisticRegression(random_state=42, solver='liblinear'), models__C=8, preprocessor__num__scaler=MinMaxScaler(); total time=   0.0s
# [CV] END feature_selection__k=all, models=LogisticRegression(random_state=42, solver='liblinear'), models__C=8, preprocessor__num__scaler=MinMaxScaler(); total time=   0.0s
# [CV] END feature_selection__k=all, models=LogisticRegression(random_state=42, solver='liblinear'), models__C=13, preprocessor__num__scaler=MinMaxScaler(); total time=   0.0s
# [CV] END feature_selection__k=all, models=LogisticRegression(random_state=42, solver='liblinear'), models__C=13, preprocessor__num__scaler=MinMaxScaler(); total time=   0.0s
# [CV] END feature_selection__k=all, models=LogisticRegression(random_state=42, solver='liblinear'), models__C=14, preprocessor__num__scaler=StandardScaler(); total time=   0.0s
# [CV] END feature_selection__k=all, models=LogisticRegression(random_state=42, solver='liblinear'), models__C=14, preprocessor__num__scaler=StandardScaler(); total time=   0.0s
# [CV] END feature_selection__k=10, models=RandomForestClassifier(random_state=42), models__max_depth=5, models__min_samples_split=2, models__n_estimators=100; total time=   0.3s
# [CV] END feature_selection__k=10, models=RandomForestClassifier(random_state=42), models__max_depth=5, models__min_samples_split=2, models__n_estimators=100; total time=   0.3s
# [CV] END feature_selection__k=10, models=RandomForestClassifier(random_state=42), models__max_depth=5, models__min_samples_split=2, models__n_estimators=100; total time=   0.3s
# [CV] END feature_selection__k=10, models=RandomForestClassifier(random_state=42), models__max_depth=5, models__min_samples_split=2, models__n_estimators=200; total time=   0.7s
# [CV] END feature_selection__k=10, models=RandomForestClassifier(random_state=42), models__max_depth=5, models__min_samples_split=5, models__n_estimators=100; total time=   0.3s
# [CV] END feature_selection__k=10, models=RandomForestClassifier(random_state=42), models__max_depth=5, models__min_samples_split=5, models__n_estimators=200; total time=   0.7s
# [CV] END feature_selection__k=10, models=RandomForestClassifier(random_state=42), models__max_depth=5, models__min_samples_split=5, models__n_estimators=200; total time=   0.7s
# [CV] END feature_selection__k=10, models=RandomForestClassifier(random_state=42), models__max_depth=5, models__min_samples_split=5, models__n_estimators=200; total time=   0.7s
# [CV] END feature_selection__k=all, models=RandomForestClassifier(random_state=42), models__max_depth=5, models__min_samples_split=5, models__n_estimators=200; total time=   0.7s
# [CV] END feature_selection__k=all, models=RandomForestClassifier(random_state=42), models__max_depth=10, models__min_samples_split=2, models__n_estimators=200; total time=   1.0s
# [CV] END .....model__C=0.0774263682681127, model__penalty=l1; total time=   0.1s
# [CV] END ....model__C=0.21544346900318834, model__penalty=l1; total time=   0.0s
# [CV] END ....model__C=0.21544346900318834, model__penalty=l1; total time=   0.1s
# [CV] END .....model__C=12.915496650148826, model__penalty=l1; total time=   0.0s
# [CV] END .....model__C=12.915496650148826, model__penalty=l1; total time=   0.1s
# [CV] END ...model__C=0.027825594022071243, model__penalty=l2; total time=   0.1s
# [CV] END ...model__C=0.027825594022071243, model__penalty=l2; total time=   0.0s
# [CV] END ...model__C=0.027825594022071243, model__penalty=l2; total time=   0.0s
# [CV] END ...model__C=0.027825594022071243, model__penalty=l2; total time=   0.0s
# [CV] END .....model__C=12.915496650148826, model__penalty=l2; total time=   0.0s
# [CV] END .....model__C=12.915496650148826, model__penalty=l2; total time=   0.0s
# [CV] END ......model__C=35.93813663804626, model__penalty=l2; total time=   0.0s
# [CV] END ......model__C=35.93813663804626, model__penalty=l2; total time=   0.0s
# [CV] END model__C=0.01, model__l1_ratio=0.9, model__penalty=elasticnet; total time=   0.0s
# [CV] END model__C=0.01, model__l1_ratio=0.9, model__penalty=elasticnet; total time=   0.0s
# [CV] END model__C=0.01, model__l1_ratio=0.9, model__penalty=elasticnet; total time=   0.0s
# [CV] END model__C=0.027825594022071243, model__l1_ratio=0.1, model__penalty=elasticnet; total time=   0.1s
# [CV] END model__C=0.0774263682681127, model__l1_ratio=0.9, model__penalty=elasticnet; total time=   0.1s
# [CV] END model__C=0.21544346900318834, model__l1_ratio=0.1, model__penalty=elasticnet; total time=   0.1s
# [CV] END model__C=0.21544346900318834, model__l1_ratio=0.1, model__penalty=elasticnet; total time=   0.1s
# [CV] END model__C=0.21544346900318834, model__l1_ratio=0.1, model__penalty=elasticnet; total time=   0.1s
# [CV] END model__C=1.6681005372000592, model__l1_ratio=0.1, model__penalty=elasticnet; total time=   0.1s
# [CV] END model__C=1.6681005372000592, model__l1_ratio=0.1, model__penalty=elasticnet; total time=   0.1s
# [CV] END model__C=1.6681005372000592, model__l1_ratio=0.1, model__penalty=elasticnet; total time=   0.0s
# [CV] END model__C=1.6681005372000592, model__l1_ratio=0.1, model__penalty=elasticnet; total time=   0.1s
# [CV] END model__C=4.6415888336127775, model__l1_ratio=0.9, model__penalty=elasticnet; total time=   0.0s
# [CV] END model__C=12.915496650148826, model__l1_ratio=0.1, model__penalty=elasticnet; total time=   0.0s
# [CV] END model__C=12.915496650148826, model__l1_ratio=0.1, model__penalty=elasticnet; total time=   0.1s
# [CV] END model__C=12.915496650148826, model__l1_ratio=0.1, model__penalty=elasticnet; total time=   0.1s
# [CV] END model__C=35.93813663804626, model__l1_ratio=0.9, model__penalty=elasticnet; total time=   0.1s
# [CV] END model__C=35.93813663804626, model__l1_ratio=0.9, model__penalty=elasticnet; total time=   0.1s
# [CV] END model__C=35.93813663804626, model__l1_ratio=0.9, model__penalty=elasticnet; total time=   0.0s
# [CV] END model__C=100.0, model__l1_ratio=0.1, model__penalty=elasticnet; total time=   0.0s
# [CV] END feature_selection__k=5, models=<catboost.core.CatBoostClassifier object at 0x10c823a10>, models__depth=4, models__iterations=100, models__learning_rate=0.03; total time=   0.2s
# [CV] END feature_selection__k=5, models=<catboost.core.CatBoostClassifier object at 0x118457c50>, models__depth=4, models__iterations=200, models__learning_rate=0.1; total time=   0.4s
# [CV] END feature_selection__k=5, models=<catboost.core.CatBoostClassifier object at 0x1184a2fd0>, models__depth=6, models__iterations=200, models__learning_rate=0.03; total time=   0.7s
# [CV] END feature_selection__k=5, models=<catboost.core.CatBoostClassifier object at 0x1184ee470>, models__depth=8, models__iterations=200, models__learning_rate=0.1; total time=   1.5s
# [CV] END feature_selection__k=10, models=<catboost.core.CatBoostClassifier object at 0x103a8bd50>, models__depth=8, models__iterations=100, models__learning_rate=0.03; total time=   0.6s
# [CV] END feature_selection__k=10, models=<catboost.core.CatBoostClassifier object at 0x1187e45f0>, models__depth=8, models__iterations=200, models__learning_rate=0.1; total time=   1.8s
# [CV] END feature_selection__k=5, models=LGBMClassifier(verbose=-1), models__learning_rate=0.05, models__max_depth=5, models__n_estimators=100; total time=   0.3s
# [CV] END feature_selection__k=5, models=LGBMClassifier(verbose=-1), models__learning_rate=0.05, models__max_depth=5, models__n_estimators=100; total time=   0.7s
# [CV] END feature_selection__k=5, models=LGBMClassifier(verbose=-1), models__learning_rate=0.05, models__max_depth=10, models__n_estimators=200; total time=   4.1s
# [CV] END feature_selection__k=5, models=LGBMClassifier(verbose=-1), models__learning_rate=0.1, models__max_depth=10, models__n_estimators=100; total time=   1.9s
# [CV] END feature_selection__k=10, models=LGBMClassifier(verbose=-1), models__learning_rate=0.05, models__max_depth=5, models__n_estimators=200; total time=   2.2s
# [CV] END feature_selection__k=10, models=LGBMClassifier(verbose=-1), models__learning_rate=0.05, models__max_depth=10, models__n_estimators=200; total time=   3.7s
# [CV] END feature_selection__k=10, models=LGBMClassifier(verbose=-1), models__learning_rate=0.1, models__max_depth=10, models__n_estimators=200; total time=   3.5s
# [CV] END feature_selection__k=all, models=LGBMClassifier(verbose=-1), models__learning_rate=0.1, models__max_depth=5, models__n_estimators=100; total time=   1.1s
# [CV] END feature_selection__k=all, models=LGBMClassifier(verbose=-1), models__learning_rate=0.1, models__max_depth=10, models__n_estimators=100; total time=   2.0s
# [CV] END feature_selection__k=5, models=LogisticRegression(random_state=42, solver='liblinear'), models__C=1, preprocessor__num__scaler=MinMaxScaler(); total time=   0.1s
# [CV] END feature_selection__k=5, models=LogisticRegression(random_state=42, solver='liblinear'), models__C=2, preprocessor__num__scaler=StandardScaler(); total time=   0.1s
# [CV] END feature_selection__k=5, models=LogisticRegression(random_state=42, solver='liblinear'), models__C=2, preprocessor__num__scaler=MinMaxScaler(); total time=   0.0s
# [CV] END feature_selection__k=5, models=LogisticRegression(random_state=42, solver='liblinear'), models__C=3, preprocessor__num__scaler=StandardScaler(); total time=   0.1s
# [CV] END feature_selection__k=5, models=LogisticRegression(random_state=42, solver='liblinear'), models__C=3, preprocessor__num__scaler=MinMaxScaler(); total time=   0.1s
# [CV] END feature_selection__k=5, models=LogisticRegression(random_state=42, solver='liblinear'), models__C=4, preprocessor__num__scaler=StandardScaler(); total time=   0.0s
# [CV] END feature_selection__k=5, models=LogisticRegression(random_state=42, solver='liblinear'), models__C=4, preprocessor__num__scaler=MinMaxScaler(); total time=   0.0s
# [CV] END feature_selection__k=5, models=LogisticRegression(random_state=42, solver='liblinear'), models__C=6, preprocessor__num__scaler=StandardScaler(); total time=   0.0s
# [CV] END feature_selection__k=5, models=LogisticRegression(random_state=42, solver='liblinear'), models__C=7, preprocessor__num__scaler=StandardScaler(); total time=   0.0s
# [CV] END feature_selection__k=5, models=LogisticRegression(random_state=42, solver='liblinear'), models__C=7, preprocessor__num__scaler=MinMaxScaler(); total time=   0.0s
# [CV] END feature_selection__k=5, models=LogisticRegression(random_state=42, solver='liblinear'), models__C=8, preprocessor__num__scaler=StandardScaler(); total time=   0.1s
# [CV] END feature_selection__k=5, models=LogisticRegression(random_state=42, solver='liblinear'), models__C=9, preprocessor__num__scaler=MinMaxScaler(); total time=   0.0s
# [CV] END feature_selection__k=5, models=LogisticRegression(random_state=42, solver='liblinear'), models__C=10, preprocessor__num__scaler=StandardScaler(); total time=   0.0s
# [CV] END feature_selection__k=5, models=LogisticRegression(random_state=42, solver='liblinear'), models__C=10, preprocessor__num__scaler=StandardScaler(); total time=   0.1s
# [CV] END feature_selection__k=5, models=LogisticRegression(random_state=42, solver='liblinear'), models__C=13, preprocessor__num__scaler=StandardScaler(); total time=   0.0s
# [CV] END feature_selection__k=5, models=LogisticRegression(random_state=42, solver='liblinear'), models__C=13, preprocessor__num__scaler=StandardScaler(); total time=   0.0s
# [CV] END feature_selection__k=5, models=LogisticRegression(random_state=42, solver='liblinear'), models__C=14, preprocessor__num__scaler=StandardScaler(); total time=   0.0s
# [CV] END feature_selection__k=5, models=LogisticRegression(random_state=42, solver='liblinear'), models__C=14, preprocessor__num__scaler=MinMaxScaler(); total time=   0.0s
# [CV] END feature_selection__k=10, models=LogisticRegression(random_state=42, solver='liblinear'), models__C=1, preprocessor__num__scaler=MinMaxScaler(); total time=   0.0s
# [CV] END feature_selection__k=10, models=LogisticRegression(random_state=42, solver='liblinear'), models__C=1, preprocessor__num__scaler=MinMaxScaler(); total time=   0.0s
# [CV] END feature_selection__k=10, models=LogisticRegression(random_state=42, solver='liblinear'), models__C=2, preprocessor__num__scaler=StandardScaler(); total time=   0.0s
# [CV] END feature_selection__k=10, models=LogisticRegression(random_state=42, solver='liblinear'), models__C=2, preprocessor__num__scaler=StandardScaler(); total time=   0.0s
# [CV] END feature_selection__k=10, models=LogisticRegression(random_state=42, solver='liblinear'), models__C=5, preprocessor__num__scaler=MinMaxScaler(); total time=   0.1s
# [CV] END feature_selection__k=10, models=LogisticRegression(random_state=42, solver='liblinear'), models__C=5, preprocessor__num__scaler=MinMaxScaler(); total time=   0.0s
# [CV] END feature_selection__k=10, models=LogisticRegression(random_state=42, solver='liblinear'), models__C=6, preprocessor__num__scaler=StandardScaler(); total time=   0.0s
# [CV] END feature_selection__k=10, models=LogisticRegression(random_state=42, solver='liblinear'), models__C=6, preprocessor__num__scaler=StandardScaler(); total time=   0.0s
# [CV] END feature_selection__k=10, models=LogisticRegression(random_state=42, solver='liblinear'), models__C=9, preprocessor__num__scaler=StandardScaler(); total time=   0.0s
# [CV] END feature_selection__k=10, models=LogisticRegression(random_state=42, solver='liblinear'), models__C=9, preprocessor__num__scaler=StandardScaler(); total time=   0.0s
# [CV] END feature_selection__k=10, models=LogisticRegression(random_state=42, solver='liblinear'), models__C=9, preprocessor__num__scaler=StandardScaler(); total time=   0.0s
# [CV] END feature_selection__k=10, models=LogisticRegression(random_state=42, solver='liblinear'), models__C=9, preprocessor__num__scaler=MinMaxScaler(); total time=   0.0s
# [CV] END feature_selection__k=10, models=LogisticRegression(random_state=42, solver='liblinear'), models__C=12, preprocessor__num__scaler=StandardScaler(); total time=   0.1s
# [CV] END feature_selection__k=10, models=LogisticRegression(random_state=42, solver='liblinear'), models__C=12, preprocessor__num__scaler=MinMaxScaler(); total time=   0.1s
# [CV] END feature_selection__k=10, models=LogisticRegression(random_state=42, solver='liblinear'), models__C=12, preprocessor__num__scaler=MinMaxScaler(); total time=   0.0s
# [CV] END feature_selection__k=10, models=LogisticRegression(random_state=42, solver='liblinear'), models__C=12, preprocessor__num__scaler=MinMaxScaler(); total time=   0.0s
# [CV] END feature_selection__k=all, models=LogisticRegression(random_state=42, solver='liblinear'), models__C=5, preprocessor__num__scaler=MinMaxScaler(); total time=   0.0s
# [CV] END feature_selection__k=all, models=LogisticRegression(random_state=42, solver='liblinear'), models__C=5, preprocessor__num__scaler=MinMaxScaler(); total time=   0.0s
# [CV] END feature_selection__k=all, models=LogisticRegression(random_state=42, solver='liblinear'), models__C=6, preprocessor__num__scaler=StandardScaler(); total time=   0.0s
# [CV] END feature_selection__k=all, models=LogisticRegression(random_state=42, solver='liblinear'), models__C=6, preprocessor__num__scaler=StandardScaler(); total time=   0.0s
# [CV] END feature_selection__k=all, models=LogisticRegression(random_state=42, solver='liblinear'), models__C=10, preprocessor__num__scaler=StandardScaler(); total time=   0.1s
# [CV] END feature_selection__k=all, models=LogisticRegression(random_state=42, solver='liblinear'), models__C=10, preprocessor__num__scaler=MinMaxScaler(); total time=   0.0s
# [CV] END feature_selection__k=all, models=LogisticRegression(random_state=42, solver='liblinear'), models__C=10, preprocessor__num__scaler=MinMaxScaler(); total time=   0.0s
# [CV] END feature_selection__k=all, models=LogisticRegression(random_state=42, solver='liblinear'), models__C=10, preprocessor__num__scaler=MinMaxScaler(); total time=   0.0s
# [CV] END feature_selection__k=5, models=RandomForestClassifier(random_state=42), models__max_depth=5, models__min_samples_split=5, models__n_estimators=100; total time=   0.3s
# [CV] END feature_selection__k=5, models=RandomForestClassifier(random_state=42), models__max_depth=5, models__min_samples_split=5, models__n_estimators=200; total time=   0.7s
# [CV] END feature_selection__k=5, models=RandomForestClassifier(random_state=42), models__max_depth=5, models__min_samples_split=5, models__n_estimators=200; total time=   0.8s
# [CV] END feature_selection__k=5, models=RandomForestClassifier(random_state=42), models__max_depth=5, models__min_samples_split=5, models__n_estimators=200; total time=   0.8s
# [CV] END feature_selection__k=all, models=RandomForestClassifier(random_state=42), models__max_depth=5, models__min_samples_split=2, models__n_estimators=100; total time=   0.3s
# [CV] END feature_selection__k=all, models=RandomForestClassifier(random_state=42), models__max_depth=5, models__min_samples_split=2, models__n_estimators=100; total time=   0.4s
# [CV] END feature_selection__k=all, models=RandomForestClassifier(random_state=42), models__max_depth=5, models__min_samples_split=2, models__n_estimators=100; total time=   0.4s
# [CV] END feature_selection__k=all, models=RandomForestClassifier(random_state=42), models__max_depth=5, models__min_samples_split=2, models__n_estimators=200; total time=   0.7s
# [CV] END feature_selection__k=all, models=RandomForestClassifier(random_state=42), models__max_depth=10, models__min_samples_split=2, models__n_estimators=100; total time=   0.5s
# [CV] END feature_selection__k=all, models=RandomForestClassifier(random_state=42), models__max_depth=10, models__min_samples_split=5, models__n_estimators=100; total time=   0.5s
# [CV] END feature_selection__k=all, models=RandomForestClassifier(random_state=42), models__max_depth=10, models__min_samples_split=5, models__n_estimators=200; total time=   0.8s
# [CV] END ...model__C=0.027825594022071243, model__penalty=l1; total time=   0.0s
# [CV] END .....model__C=0.0774263682681127, model__penalty=l1; total time=   0.1s
# [CV] END .....model__C=0.5994842503189409, model__penalty=l1; total time=   0.1s
# [CV] END .....model__C=0.5994842503189409, model__penalty=l1; total time=   0.0s
# [CV] END .....model__C=12.915496650148826, model__penalty=l1; total time=   0.0s
# [CV] END .....model__C=12.915496650148826, model__penalty=l1; total time=   0.1s
# [CV] END ..................model__C=100.0, model__penalty=l1; total time=   0.0s
# [CV] END ..................model__C=100.0, model__penalty=l1; total time=   0.0s
# [CV] END ...................model__C=0.01, model__penalty=l2; total time=   0.1s
# [CV] END ...................model__C=0.01, model__penalty=l2; total time=   0.1s
# [CV] END .....model__C=4.6415888336127775, model__penalty=l2; total time=   0.1s
# [CV] END .....model__C=12.915496650148826, model__penalty=l2; total time=   0.1s
# [CV] END .....model__C=12.915496650148826, model__penalty=l2; total time=   0.0s
# [CV] END .....model__C=12.915496650148826, model__penalty=l2; total time=   0.0s
# [CV] END model__C=0.027825594022071243, model__l1_ratio=0.5, model__penalty=elasticnet; total time=   0.0s
# [CV] END model__C=0.027825594022071243, model__l1_ratio=0.5, model__penalty=elasticnet; total time=   0.0s
# [CV] END model__C=0.027825594022071243, model__l1_ratio=0.5, model__penalty=elasticnet; total time=   0.0s
# [CV] END model__C=0.027825594022071243, model__l1_ratio=0.5, model__penalty=elasticnet; total time=   0.0s
# [CV] END model__C=0.21544346900318834, model__l1_ratio=0.5, model__penalty=elasticnet; total time=   0.0s
# [CV] END model__C=0.21544346900318834, model__l1_ratio=0.5, model__penalty=elasticnet; total time=   0.1s
# [CV] END model__C=0.21544346900318834, model__l1_ratio=0.5, model__penalty=elasticnet; total time=   0.0s
# [CV] END model__C=0.21544346900318834, model__l1_ratio=0.9, model__penalty=elasticnet; total time=   0.1s
# [CV] END model__C=1.6681005372000592, model__l1_ratio=0.5, model__penalty=elasticnet; total time=   0.0s
# [CV] END model__C=1.6681005372000592, model__l1_ratio=0.5, model__penalty=elasticnet; total time=   0.0s
# [CV] END model__C=1.6681005372000592, model__l1_ratio=0.5, model__penalty=elasticnet; total time=   0.1s
# [CV] END model__C=1.6681005372000592, model__l1_ratio=0.5, model__penalty=elasticnet; total time=   0.1s
# [CV] END model__C=12.915496650148826, model__l1_ratio=0.9, model__penalty=elasticnet; total time=   0.0s
# [CV] END model__C=12.915496650148826, model__l1_ratio=0.9, model__penalty=elasticnet; total time=   0.1s
# [CV] END model__C=12.915496650148826, model__l1_ratio=0.9, model__penalty=elasticnet; total time=   0.1s
# [CV] END model__C=12.915496650148826, model__l1_ratio=0.9, model__penalty=elasticnet; total time=   0.0s
# [CV] END model__C=100.0, model__l1_ratio=0.5, model__penalty=elasticnet; total time=   0.0s
# [CV] END model__C=100.0, model__l1_ratio=0.9, model__penalty=elasticnet; total time=   0.1s
# [CV] END feature_selection__k=5, models=<catboost.core.CatBoostClassifier object at 0x11e72ba10>, models__depth=4, models__iterations=100, models__learning_rate=0.1; total time=   0.2s
# [CV] END feature_selection__k=5, models=<catboost.core.CatBoostClassifier object at 0x128d57c50>, models__depth=6, models__iterations=100, models__learning_rate=0.03; total time=   0.2s
# [CV] END feature_selection__k=5, models=<catboost.core.CatBoostClassifier object at 0x128da2fd0>, models__depth=6, models__iterations=100, models__learning_rate=0.1; total time=   0.2s
# [CV] END feature_selection__k=5, models=<catboost.core.CatBoostClassifier object at 0x128dee470>, models__depth=6, models__iterations=200, models__learning_rate=0.1; total time=   0.8s
# [CV] END feature_selection__k=10, models=<catboost.core.CatBoostClassifier object at 0x106413d50>, models__depth=4, models__iterations=100, models__learning_rate=0.03; total time=   0.2s
# [CV] END feature_selection__k=10, models=<catboost.core.CatBoostClassifier object at 0x128ee45f0>, models__depth=4, models__iterations=100, models__learning_rate=0.1; total time=   0.3s
# [CV] END feature_selection__k=10, models=<catboost.core.CatBoostClassifier object at 0x128e99ef0>, models__depth=4, models__iterations=200, models__learning_rate=0.1; total time=   0.3s
# [CV] END feature_selection__k=10, models=<catboost.core.CatBoostClassifier object at 0x128ec0ae0>, models__depth=6, models__iterations=100, models__learning_rate=0.03; total time=   0.2s
# [CV] END feature_selection__k=10, models=<catboost.core.CatBoostClassifier object at 0x128e49010>, models__depth=6, models__iterations=200, models__learning_rate=0.03; total time=   0.4s
# [CV] END feature_selection__k=10, models=<catboost.core.CatBoostClassifier object at 0x128dfb960>, models__depth=8, models__iterations=100, models__learning_rate=0.03; total time=   0.3s
# [CV] END feature_selection__k=10, models=<catboost.core.CatBoostClassifier object at 0x128ea68f0>, models__depth=8, models__iterations=200, models__learning_rate=0.03; total time=   0.7s
# [CV] END feature_selection__k=all, models=<catboost.core.CatBoostClassifier object at 0x11f2b4cb0>, models__depth=4, models__iterations=200, models__learning_rate=0.03; total time=   0.4s
# [CV] END feature_selection__k=all, models=<catboost.core.CatBoostClassifier object at 0x11f2b4cb0>, models__depth=6, models__iterations=100, models__learning_rate=0.03; total time=   0.1s
# [CV] END feature_selection__k=all, models=<catboost.core.CatBoostClassifier object at 0x11f2b4cb0>, models__depth=6, models__iterations=200, models__learning_rate=0.03; total time=   0.4s
# [CV] END feature_selection__k=all, models=<catboost.core.CatBoostClassifier object at 0x11f2b4cb0>, models__depth=8, models__iterations=100, models__learning_rate=0.03; total time=   0.3s
# [CV] END feature_selection__k=all, models=<catboost.core.CatBoostClassifier object at 0x11f2b4cb0>, models__depth=8, models__iterations=200, models__learning_rate=0.03; total time=   0.9s
# [CV] END feature_selection__k=5, models=LGBMClassifier(verbose=-1), models__learning_rate=0.05, models__max_depth=5, models__n_estimators=200; total time=   2.0s
# [CV] END feature_selection__k=5, models=LGBMClassifier(verbose=-1), models__learning_rate=0.05, models__max_depth=10, models__n_estimators=200; total time=   4.0s
# [CV] END feature_selection__k=10, models=LGBMClassifier(verbose=-1), models__learning_rate=0.05, models__max_depth=5, models__n_estimators=200; total time=   2.2s
# [CV] END feature_selection__k=10, models=LGBMClassifier(verbose=-1), models__learning_rate=0.05, models__max_depth=10, models__n_estimators=100; total time=   2.0s
# [CV] END feature_selection__k=10, models=LGBMClassifier(verbose=-1), models__learning_rate=0.1, models__max_depth=10, models__n_estimators=100; total time=   2.0s
# [CV] END feature_selection__k=all, models=LGBMClassifier(verbose=-1), models__learning_rate=0.05, models__max_depth=5, models__n_estimators=100; total time=   1.0s
# [CV] END feature_selection__k=all, models=LGBMClassifier(verbose=-1), models__learning_rate=0.05, models__max_depth=5, models__n_estimators=200; total time=   2.4s
# [CV] END feature_selection__k=all, models=LGBMClassifier(verbose=-1), models__learning_rate=0.1, models__max_depth=5, models__n_estimators=100; total time=   1.1s
# [CV] END feature_selection__k=all, models=LGBMClassifier(verbose=-1), models__learning_rate=0.1, models__max_depth=10, models__n_estimators=100; total time=   1.9s
# [CV] END feature_selection__k=all, models=LGBMClassifier(verbose=-1), models__learning_rate=0.1, models__max_depth=10, models__n_estimators=200; total time=   1.9s
# [CV] END feature_selection__k=all, models=LogisticRegression(random_state=42, solver='liblinear'), models__C=1, preprocessor__num__scaler=StandardScaler(); total time=   0.0s
# [CV] END feature_selection__k=all, models=LogisticRegression(random_state=42, solver='liblinear'), models__C=1, preprocessor__num__scaler=StandardScaler(); total time=   0.0s
# [CV] END feature_selection__k=all, models=LogisticRegression(random_state=42, solver='liblinear'), models__C=1, preprocessor__num__scaler=StandardScaler(); total time=   0.0s
# [CV] END feature_selection__k=all, models=LogisticRegression(random_state=42, solver='liblinear'), models__C=1, preprocessor__num__scaler=MinMaxScaler(); total time=   0.0s
# [CV] END feature_selection__k=all, models=LogisticRegression(random_state=42, solver='liblinear'), models__C=7, preprocessor__num__scaler=StandardScaler(); total time=   0.0s
# [CV] END feature_selection__k=all, models=LogisticRegression(random_state=42, solver='liblinear'), models__C=7, preprocessor__num__scaler=StandardScaler(); total time=   0.0s
# [CV] END feature_selection__k=all, models=LogisticRegression(random_state=42, solver='liblinear'), models__C=7, preprocessor__num__scaler=StandardScaler(); total time=   0.0s
# [CV] END feature_selection__k=all, models=LogisticRegression(random_state=42, solver='liblinear'), models__C=7, preprocessor__num__scaler=MinMaxScaler(); total time=   0.0s
# [CV] END feature_selection__k=all, models=LogisticRegression(random_state=42, solver='liblinear'), models__C=11, preprocessor__num__scaler=MinMaxScaler(); total time=   0.0s
# [CV] END feature_selection__k=all, models=LogisticRegression(random_state=42, solver='liblinear'), models__C=11, preprocessor__num__scaler=MinMaxScaler(); total time=   0.0s
# [CV] END feature_selection__k=all, models=LogisticRegression(random_state=42, solver='liblinear'), models__C=12, preprocessor__num__scaler=StandardScaler(); total time=   0.0s
# [CV] END feature_selection__k=all, models=LogisticRegression(random_state=42, solver='liblinear'), models__C=12, preprocessor__num__scaler=StandardScaler(); total time=   0.0s
# [CV] END feature_selection__k=5, models=RandomForestClassifier(random_state=42), models__max_depth=10, models__min_samples_split=2, models__n_estimators=100; total time=   0.6s
# [CV] END feature_selection__k=5, models=RandomForestClassifier(random_state=42), models__max_depth=10, models__min_samples_split=2, models__n_estimators=100; total time=   0.6s
# [CV] END feature_selection__k=5, models=RandomForestClassifier(random_state=42), models__max_depth=10, models__min_samples_split=2, models__n_estimators=100; total time=   0.6s
# [CV] END feature_selection__k=5, models=RandomForestClassifier(random_state=42), models__max_depth=10, models__min_samples_split=2, models__n_estimators=200; total time=   1.1s
# [CV] END feature_selection__k=all, models=RandomForestClassifier(random_state=42), models__max_depth=5, models__min_samples_split=2, models__n_estimators=200; total time=   0.7s
# [CV] END feature_selection__k=all, models=RandomForestClassifier(random_state=42), models__max_depth=5, models__min_samples_split=2, models__n_estimators=200; total time=   0.7s
# [CV] END feature_selection__k=all, models=RandomForestClassifier(random_state=42), models__max_depth=5, models__min_samples_split=5, models__n_estimators=100; total time=   0.4s
# [CV] END feature_selection__k=all, models=RandomForestClassifier(random_state=42), models__max_depth=5, models__min_samples_split=5, models__n_estimators=100; total time=   0.3s
# [CV] END feature_selection__k=all, models=RandomForestClassifier(random_state=42), models__max_depth=10, models__min_samples_split=2, models__n_estimators=200; total time=   1.0s
# [CV] END ...model__C=0.027825594022071243, model__penalty=l1; total time=   0.0s
# [CV] END .....model__C=1.6681005372000592, model__penalty=l1; total time=   0.1s
# [CV] END .....model__C=1.6681005372000592, model__penalty=l1; total time=   0.1s
# [CV] END ......model__C=35.93813663804626, model__penalty=l1; total time=   0.0s
# [CV] END ......model__C=35.93813663804626, model__penalty=l1; total time=   0.1s
# [CV] END .....model__C=0.0774263682681127, model__penalty=l2; total time=   0.0s
# ...
# [CV] END feature_selection__k=5, models=<catboost.core.CatBoostClassifier object at 0x1376a2fd0>, models__depth=6, models__iterations=200, models__learning_rate=0.1; total time=   0.4s
# [CV] END feature_selection__k=5, models=<catboost.core.CatBoostClassifier object at 0x1376ee470>, models__depth=8, models__iterations=100, models__learning_rate=0.1; total time=   0.2s
# [CV] END feature_selection__k=5, models=<catboost.core.CatBoostClassifier object at 0x100fefd50>, models__depth=8, models__iterations=200, models__learning_rate=0.1; total time=   0.5s
# [CV] END feature_selection__k=10, models=<catboost.core.CatBoostClassifier object at 0x1377d05f0>, models__depth=4, models__iterations=200, models__learning_rate=0.03; total time=   0.3s
# [CV] END feature_selection__k=10, models=<catboost.core.CatBoostClassifier object at 0x137795ef0>, models__depth=4, models__iterations=200, models__learning_rate=0.1; total time=   0.3s
# [CV] END feature_selection__k=10, models=<catboost.core.CatBoostClassifier object at 0x1377e4ae0>, models__depth=6, models__iterations=200, models__learning_rate=0.03; total time=   0.4s
# [CV] END feature_selection__k=10, models=<catboost.core.CatBoostClassifier object at 0x137749010>, models__depth=8, models__iterations=100, models__learning_rate=0.1; total time=   0.3s
# [CV] END feature_selection__k=10, models=<catboost.core.CatBoostClassifier object at 0x1376fb960>, models__depth=8, models__iterations=200, models__learning_rate=0.1; total time=   0.7s
# [CV] END feature_selection__k=all, models=<catboost.core.CatBoostClassifier object at 0x1377a68f0>, models__depth=4, models__iterations=200, models__learning_rate=0.03; total time=   0.3s
# [CV] END feature_selection__k=all, models=<catboost.core.CatBoostClassifier object at 0x132954cb0>, models__depth=6, models__iterations=100, models__learning_rate=0.03; total time=   0.2s
# [CV] END feature_selection__k=all, models=<catboost.core.CatBoostClassifier object at 0x132954cb0>, models__depth=6, models__iterations=200, models__learning_rate=0.03; total time=   0.4s
# [CV] END feature_selection__k=all, models=<catboost.core.CatBoostClassifier object at 0x132954cb0>, models__depth=8, models__iterations=100, models__learning_rate=0.03; total time=   0.3s
# [CV] END feature_selection__k=all, models=<catboost.core.CatBoostClassifier object at 0x132954cb0>, models__depth=8, models__iterations=200, models__learning_rate=0.03; total time=   1.0s
# [CV] END feature_selection__k=5, models=LGBMClassifier(verbose=-1), models__learning_rate=0.05, models__max_depth=5, models__n_estimators=200; total time=   2.4s
# [CV] END feature_selection__k=5, models=LGBMClassifier(verbose=-1), models__learning_rate=0.1, models__max_depth=5, models__n_estimators=100; total time=   1.0s
# [CV] END feature_selection__k=5, models=LGBMClassifier(verbose=-1), models__learning_rate=0.1, models__max_depth=10, models__n_estimators=100; total time=   1.9s
# [CV] END feature_selection__k=10, models=LGBMClassifier(verbose=-1), models__learning_rate=0.05, models__max_depth=5, models__n_estimators=100; total time=   1.2s
# [CV] END feature_selection__k=10, models=LGBMClassifier(verbose=-1), models__learning_rate=0.05, models__max_depth=10, models__n_estimators=100; total time=   2.2s
# [CV] END feature_selection__k=10, models=LGBMClassifier(verbose=-1), models__learning_rate=0.05, models__max_depth=10, models__n_estimators=200; total time=   3.7s
# [CV] END feature_selection__k=all, models=LGBMClassifier(verbose=-1), models__learning_rate=0.05, models__max_depth=5, models__n_estimators=200; total time=   2.0s
# [CV] END feature_selection__k=all, models=LGBMClassifier(verbose=-1), models__learning_rate=0.05, models__max_depth=10, models__n_estimators=100; total time=   2.1s
# [CV] END feature_selection__k=all, models=LGBMClassifier(verbose=-1), models__learning_rate=0.1, models__max_depth=5, models__n_estimators=200; total time=   2.1s
# [CV] END feature_selection__k=5, models=LogisticRegression(random_state=42, solver='liblinear'), models__C=1, preprocessor__num__scaler=StandardScaler(); total time=   0.1s
# [CV] END feature_selection__k=5, models=LogisticRegression(random_state=42, solver='liblinear'), models__C=1, preprocessor__num__scaler=StandardScaler(); total time=   0.0s
# [CV] END feature_selection__k=5, models=LogisticRegression(random_state=42, solver='liblinear'), models__C=1, preprocessor__num__scaler=MinMaxScaler(); total time=   0.1s
# [CV] END feature_selection__k=5, models=LogisticRegression(random_state=42, solver='liblinear'), models__C=2, preprocessor__num__scaler=StandardScaler(); total time=   0.1s
# [CV] END feature_selection__k=5, models=LogisticRegression(random_state=42, solver='liblinear'), models__C=2, preprocessor__num__scaler=MinMaxScaler(); total time=   0.0s
# [CV] END feature_selection__k=5, models=LogisticRegression(random_state=42, solver='liblinear'), models__C=3, preprocessor__num__scaler=StandardScaler(); total time=   0.1s
# [CV] END feature_selection__k=5, models=LogisticRegression(random_state=42, solver='liblinear'), models__C=3, preprocessor__num__scaler=MinMaxScaler(); total time=   0.1s
# [CV] END feature_selection__k=5, models=LogisticRegression(random_state=42, solver='liblinear'), models__C=4, preprocessor__num__scaler=StandardScaler(); total time=   0.0s
# [CV] END feature_selection__k=5, models=LogisticRegression(random_state=42, solver='liblinear'), models__C=4, preprocessor__num__scaler=MinMaxScaler(); total time=   0.0s
# [CV] END feature_selection__k=5, models=LogisticRegression(random_state=42, solver='liblinear'), models__C=5, preprocessor__num__scaler=MinMaxScaler(); total time=   0.0s
# [CV] END feature_selection__k=5, models=LogisticRegression(random_state=42, solver='liblinear'), models__C=6, preprocessor__num__scaler=StandardScaler(); total time=   0.0s
# [CV] END feature_selection__k=5, models=LogisticRegression(random_state=42, solver='liblinear'), models__C=7, preprocessor__num__scaler=StandardScaler(); total time=   0.0s
# [CV] END feature_selection__k=5, models=LogisticRegression(random_state=42, solver='liblinear'), models__C=8, preprocessor__num__scaler=StandardScaler(); total time=   0.0s
# [CV] END feature_selection__k=5, models=LogisticRegression(random_state=42, solver='liblinear'), models__C=8, preprocessor__num__scaler=MinMaxScaler(); total time=   0.0s
# [CV] END feature_selection__k=5, models=LogisticRegression(random_state=42, solver='liblinear'), models__C=9, preprocessor__num__scaler=MinMaxScaler(); total time=   0.0s
# [CV] END feature_selection__k=5, models=LogisticRegression(random_state=42, solver='liblinear'), models__C=9, preprocessor__num__scaler=MinMaxScaler(); total time=   0.0s
# [CV] END feature_selection__k=5, models=LogisticRegression(random_state=42, solver='liblinear'), models__C=11, preprocessor__num__scaler=StandardScaler(); total time=   0.0s
# [CV] END feature_selection__k=5, models=LogisticRegression(random_state=42, solver='liblinear'), models__C=11, preprocessor__num__scaler=MinMaxScaler(); total time=   0.0s
# [CV] END feature_selection__k=5, models=LogisticRegression(random_state=42, solver='liblinear'), models__C=12, preprocessor__num__scaler=MinMaxScaler(); total time=   0.0s
# [CV] END feature_selection__k=5, models=LogisticRegression(random_state=42, solver='liblinear'), models__C=12, preprocessor__num__scaler=MinMaxScaler(); total time=   0.1s
# [CV] END feature_selection__k=10, models=LogisticRegression(random_state=42, solver='liblinear'), models__C=3, preprocessor__num__scaler=StandardScaler(); total time=   0.0s
# [CV] END feature_selection__k=10, models=LogisticRegression(random_state=42, solver='liblinear'), models__C=3, preprocessor__num__scaler=StandardScaler(); total time=   0.0s
# [CV] END feature_selection__k=10, models=LogisticRegression(random_state=42, solver='liblinear'), models__C=3, preprocessor__num__scaler=StandardScaler(); total time=   0.0s
# [CV] END feature_selection__k=10, models=LogisticRegression(random_state=42, solver='liblinear'), models__C=3, preprocessor__num__scaler=MinMaxScaler(); total time=   0.0s
# [CV] END feature_selection__k=10, models=LogisticRegression(random_state=42, solver='liblinear'), models__C=4, preprocessor__num__scaler=StandardScaler(); total time=   0.0s
# [CV] END feature_selection__k=10, models=LogisticRegression(random_state=42, solver='liblinear'), models__C=4, preprocessor__num__scaler=MinMaxScaler(); total time=   0.0s
# [CV] END feature_selection__k=10, models=LogisticRegression(random_state=42, solver='liblinear'), models__C=4, preprocessor__num__scaler=MinMaxScaler(); total time=   0.0s
# [CV] END feature_selection__k=10, models=LogisticRegression(random_state=42, solver='liblinear'), models__C=4, preprocessor__num__scaler=MinMaxScaler(); total time=   0.0s
# [CV] END feature_selection__k=10, models=LogisticRegression(random_state=42, solver='liblinear'), models__C=7, preprocessor__num__scaler=MinMaxScaler(); total time=   0.0s
# [CV] END feature_selection__k=10, models=LogisticRegression(random_state=42, solver='liblinear'), models__C=7, preprocessor__num__scaler=MinMaxScaler(); total time=   0.0s
# [CV] END feature_selection__k=10, models=LogisticRegression(random_state=42, solver='liblinear'), models__C=8, preprocessor__num__scaler=StandardScaler(); total time=   0.0s
# [CV] END feature_selection__k=10, models=LogisticRegression(random_state=42, solver='liblinear'), models__C=8, preprocessor__num__scaler=StandardScaler(); total time=   0.0s
# [CV] END feature_selection__k=10, models=LogisticRegression(random_state=42, solver='liblinear'), models__C=11, preprocessor__num__scaler=StandardScaler(); total time=   0.0s
# [CV] END feature_selection__k=10, models=LogisticRegression(random_state=42, solver='liblinear'), models__C=11, preprocessor__num__scaler=StandardScaler(); total time=   0.0s
# [CV] END feature_selection__k=10, models=LogisticRegression(random_state=42, solver='liblinear'), models__C=11, preprocessor__num__scaler=StandardScaler(); total time=   0.1s
# [CV] END feature_selection__k=10, models=LogisticRegression(random_state=42, solver='liblinear'), models__C=11, preprocessor__num__scaler=MinMaxScaler(); total time=   0.0s
# [CV] END feature_selection__k=all, models=LogisticRegression(random_state=42, solver='liblinear'), models__C=2, preprocessor__num__scaler=StandardScaler(); total time=   0.0s
# [CV] END feature_selection__k=all, models=LogisticRegression(random_state=42, solver='liblinear'), models__C=2, preprocessor__num__scaler=MinMaxScaler(); total time=   0.0s
# [CV] END feature_selection__k=all, models=LogisticRegression(random_state=42, solver='liblinear'), models__C=2, preprocessor__num__scaler=MinMaxScaler(); total time=   0.0s
# [CV] END feature_selection__k=all, models=LogisticRegression(random_state=42, solver='liblinear'), models__C=2, preprocessor__num__scaler=MinMaxScaler(); total time=   0.0s
# [CV] END feature_selection__k=all, models=LogisticRegression(random_state=42, solver='liblinear'), models__C=7, preprocessor__num__scaler=MinMaxScaler(); total time=   0.0s
# [CV] END feature_selection__k=all, models=LogisticRegression(random_state=42, solver='liblinear'), models__C=7, preprocessor__num__scaler=MinMaxScaler(); total time=   0.0s
# [CV] END feature_selection__k=all, models=LogisticRegression(random_state=42, solver='liblinear'), models__C=8, preprocessor__num__scaler=StandardScaler(); total time=   0.0s
# [CV] END feature_selection__k=all, models=LogisticRegression(random_state=42, solver='liblinear'), models__C=8, preprocessor__num__scaler=StandardScaler(); total time=   0.0s
# [CV] END feature_selection__k=all, models=LogisticRegression(random_state=42, solver='liblinear'), models__C=13, preprocessor__num__scaler=StandardScaler(); total time=   0.0s
# [CV] END feature_selection__k=all, models=LogisticRegression(random_state=42, solver='liblinear'), models__C=13, preprocessor__num__scaler=StandardScaler(); total time=   0.0s
# [CV] END feature_selection__k=all, models=LogisticRegression(random_state=42, solver='liblinear'), models__C=13, preprocessor__num__scaler=StandardScaler(); total time=   0.0s
# [CV] END feature_selection__k=all, models=LogisticRegression(random_state=42, solver='liblinear'), models__C=13, preprocessor__num__scaler=MinMaxScaler(); total time=   0.0s
# [CV] END feature_selection__k=5, models=RandomForestClassifier(random_state=42), models__max_depth=10, models__min_samples_split=5, models__n_estimators=100; total time=   0.6s
# [CV] END feature_selection__k=5, models=RandomForestClassifier(random_state=42), models__max_depth=10, models__min_samples_split=5, models__n_estimators=200; total time=   1.1s
# [CV] END feature_selection__k=5, models=RandomForestClassifier(random_state=42), models__max_depth=10, models__min_samples_split=5, models__n_estimators=200; total time=   1.1s
# [CV] END feature_selection__k=5, models=RandomForestClassifier(random_state=42), models__max_depth=10, models__min_samples_split=5, models__n_estimators=200; total time=   1.1s
# [CV] END feature_selection__k=all, models=RandomForestClassifier(random_state=42), models__max_depth=5, models__min_samples_split=5, models__n_estimators=200; total time=   0.6s
# [CV] END feature_selection__k=all, models=RandomForestClassifier(random_state=42), models__max_depth=10, models__min_samples_split=2, models__n_estimators=200; total time=   1.0s
# [CV] END ...................model__C=0.01, model__penalty=l1; total time=   0.0s
# [CV] END .....model__C=0.0774263682681127, model__penalty=l1; total time=   0.0s
# [CV] END .....model__C=0.5994842503189409, model__penalty=l1; total time=   0.1s
# [CV] END .....model__C=1.6681005372000592, model__penalty=l1; total time=   0.1s
# [CV] END ......model__C=35.93813663804626, model__penalty=l1; total time=   0.0s
# [CV] END ......model__C=35.93813663804626, model__penalty=l1; total time=   0.0s
# [CV] END .....model__C=0.0774263682681127, model__penalty=l2; total time=   0.0s
# [CV] END .....model__C=0.0774263682681127, model__penalty=l2; total time=   0.1s
# [CV] END .....model__C=0.0774263682681127, model__penalty=l2; total time=   0.1s
# [CV] END .....model__C=0.0774263682681127, model__penalty=l2; total time=   0.1s
# [CV] END ..................model__C=100.0, model__penalty=l2; total time=   0.1s
# [CV] END ..................model__C=100.0, model__penalty=l2; total time=   0.0s
# [CV] END ..................model__C=100.0, model__penalty=l2; total time=   0.0s
# [CV] END ..................model__C=100.0, model__penalty=l2; total time=   0.0s
# [CV] END model__C=0.027825594022071243, model__l1_ratio=0.5, model__penalty=elasticnet; total time=   0.0s
# [CV] END model__C=0.027825594022071243, model__l1_ratio=0.9, model__penalty=elasticnet; total time=   0.0s
# [CV] END model__C=0.027825594022071243, model__l1_ratio=0.9, model__penalty=elasticnet; total time=   0.1s
# [CV] END model__C=0.027825594022071243, model__l1_ratio=0.9, model__penalty=elasticnet; total time=   0.1s
# [CV] END model__C=0.5994842503189409, model__l1_ratio=0.1, model__penalty=elasticnet; total time=   0.1s
# [CV] END model__C=0.5994842503189409, model__l1_ratio=0.1, model__penalty=elasticnet; total time=   0.1s
# [CV] END model__C=0.5994842503189409, model__l1_ratio=0.1, model__penalty=elasticnet; total time=   0.2s
# [CV] END model__C=0.5994842503189409, model__l1_ratio=0.1, model__penalty=elasticnet; total time=   0.1s
# [CV] END model__C=12.915496650148826, model__l1_ratio=0.5, model__penalty=elasticnet; total time=   0.1s
# [CV] END model__C=12.915496650148826, model__l1_ratio=0.5, model__penalty=elasticnet; total time=   0.0s
# [CV] END model__C=12.915496650148826, model__l1_ratio=0.5, model__penalty=elasticnet; total time=   0.1s
# [CV] END model__C=12.915496650148826, model__l1_ratio=0.9, model__penalty=elasticnet; total time=   0.0s
# [CV] END model__C=100.0, model__l1_ratio=0.5, model__penalty=elasticnet; total time=   0.0s
# [CV] END model__C=100.0, model__l1_ratio=0.5, model__penalty=elasticnet; total time=   0.1s
# [CV] END model__C=100.0, model__l1_ratio=0.9, model__penalty=elasticnet; total time=   0.1s

# %% [markdown]
# **🧾 Общий вывод по проекту**
#
# В рамках проекта была решена задача предсказания факта опоздания курьера на основе характеристик доставки. Работа прошла через все ключевые этапы ML-пайплайна:
# - Проведена глубокая предобработка данных, включая приведение к читаемым названиям и устранение дубликатов.
# - Выполнен EDA: изучены распределения признаков, их связь с целевой переменной, построены визуализации.
# - Разработана и протестирована ML-модель с приоритетом на recall (важно не пропустить опоздание).
# - Получена модель, которая:
#     - достигает recall = 0.776 на тесте;
# 	- при этом сохраняет precision = 0.663, что даёт баланс между полнотой и надёжностью.

# %% [markdown]
# **🤖 ML-часть: подробный технический разбор**
#
# 📌 1. Предобработка и структура пайплайна
# - Категориальные признаки:
# 	- gender, mode_of_shipment — OneHotEncoder;
# 	- weight_class — OrdinalEncoder (light < medium < heavy).
# - Числовые признаки масштабировались через StandardScaler или MinMaxScaler.
# - Все этапы объединены в ColumnTransformer → Pipeline.
#
# 📌 2. Feature Selection
# - Использован SelectKBest(score_func=f_classif).
# - Выбран k=5 по GridSearchCV.
# - Отобраны самые важные признаки: discount, weight, prior_purchases, price, weight_class.
#
# 📌 3. Регуляризация и модель
# - Протестированы L1, L2, ElasticNet.
# - Лучшей оказалась L1-регуляризация с C=0.01.
# - Использован solver='saga' — правильный выбор для всех трёх пенальти.
#
# 📌 4. Подбор порога классификации
# - Проведён перебор от 0.0 до 1.0 с шагом 0.01.
# - Из отрезка с recall ≥ 0.75 выбран порог с максимальным precision.
# - Лучший порог: 0.47, при котором:
# 	- recall = 0.776
# 	- precision = 0.663
#
# 📌 5. Метрики и визуализация
# - Построены:
# 	- Confusion Matrix
# 	- PR-кривая (AUC ≈ 0.836)
# 	- ROC-кривая (AUC ≈ 0.718)
# - Модель уверенно разделяет классы, особенно хорошо предсказывает “опоздание” (1).
